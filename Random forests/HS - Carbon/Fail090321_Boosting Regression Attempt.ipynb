# %%
#This code implements ADA boosting to see the effects on the model performance

# %% [markdown]
# I think adaboost in this case doesnt work effectively due to the limited amount of data. As the number of trees increases the number of data points that that tree can learn off falls considerabely and as our data set is rather small, as is evident from the graphs of the errors, when the number of trees gets larger than 20 the absolute erro rockets. If we were to use adaboosting the best no of trees would be lower, however i think we have seen better results with random forests. ADAboost is attempting to learn from preivious mistakes and then weighting trees where there was less error as more important in the final prediction. 10 trees would be the optimal n_estimators.

# %%
#importing modules for the implementation
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt 
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib as mpl
from sklearn.feature_selection import SelectFromModel

# %%
#pulling the data from the pickled dataset 
nutrition = pd.read_csv("./Nutrition_Full_Features.csv")

# %%
#dropping NANSinclude a lot of NaNs
#nutrition.drop(nutrition.columns[1:3], axis=1, inplace=True)
nutrition = nutrition.dropna()
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#extracting the nutrition data, labelling X as this is the input to the SKlearn algorithm
X = nutrition.iloc[:,11:]
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
#extracting the greenhouse gas emissions 
y = nutrition.iloc[:,7:8]
y
# Out:
#       GHG(kgco2eq/100g)
# 1                0.1441
# 2                0.1441
# 5                0.1441
# 9                0.1441
# 10               0.1441
# ...                 ...
# 1218             0.0455
# 1219             0.0455
# 1220             2.1240
# 1221             0.0455
# 1222             0.0455
#
# [1042 rows x 1 columns]

# %%
#changing y to a 1d array rather than the table 
y = np.ravel(y)
y
# Out:
# array([0.1441, 0.1441, 0.1441, ..., 2.124 , 0.0455, 0.0455])

# %%
#splitting the dataset into a test and train data set, with 20% being used for testing
from sklearn.model_selection import train_test_split
X_train_val, X_test, y_train_val, y_test = train_test_split(X,y,test_size=0.2) #size =0.2 means 80% data is training data, 20% testing

# %%
#splitting train data set into train and validation set 
X_train, X_val, y_train, y_val = train_test_split(X_train_val,y_train_val,test_size=0.15)

# %%
#importing bagging function from sklearn 
#storing the prediction from the test 
from sklearn.ensemble import AdaBoostRegressor
#importing sklearn algorithm and using it with 2000 trees 
#storing the prediction from the test 
from sklearn.ensemble import AdaBoostRegressor
model = AdaBoostRegressor(n_estimators=20)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from numpy import mean 
from numpy import std
# evaluate the model
# using a k fold cross vallidation basically completes the validation many times
# resulting in the mean result across all folds so you get a less noisy estimate of the models performance 
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#cross validation could mean we can train on more of the data, wouldnt need to define test and train sets
n_scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %%
#evaluating the model by checking errors
#generally error decreases slightly as number of trees is increased, converges around 200 trees

from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.38892047911631683
# Mean Squared Error: 0.6644935491609145
# Root Mean Squared Error: 0.8151647374371113

# %%
np.mean(y)
# Out:
# 0.8464732245681383

# %%
np.std(y)
# Out:
# 1.6110865075846403

# %%
# bagging and boosting perform on the carbon set
# boosting split it into mini data sub sections 
# adding in more of the data 


# different number of trees a for loop

# %%
#writing a for loop to pull out the error at varying n_estimators (otherwise known as the number of trees the algorithm is using)


mse = []
mae = []
rmse = []
        
for i in range(1,200,5):
    from sklearn.ensemble import AdaBoostRegressor
    model = AdaBoostRegressor(n_estimators=i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    Mean_Absolute_Error = metrics.mean_absolute_error(y_test, y_pred)
    Mean_Squared_Error = metrics.mean_squared_error(y_test, y_pred)
    Root_Mean_Squared_Error = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
   
    mse.append(Mean_Squared_Error)
    rmse.append(Root_Mean_Squared_Error)
    mae.append(Mean_Absolute_Error)

# %%
#creating a list of the number of estimators for ploting 
Number_estimators = list(range(1,200,5))


fig = plt.figure()
Absolute = plt.subplot(311)
Absolute.title.set_text('Mean Absolute Error vs Number of trees')
plt.plot(Number_estimators,mae)
plt.ylabel('Mean Absolute Error')
plt.xlabel('Number of trees')
plt.show

Square = plt.subplot(312)
Square.title.set_text('Mean Squared Error vs Number of trees')
plt.plot(Number_estimators,mse)
plt.ylabel('Mean Squared Error')
plt.xlabel('Number of trees')
plt.show

Root = plt.subplot(313)
Root.title.set_text('Root Mean Squared Error vs Number of trees')
plt.plot(Number_estimators,rmse)
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Number of trees')
plt.subplots_adjust(top= 4, bottom=2, wspace=1, hspace=0.5)
plt.savefig('Error Plots')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The cell above should run code to show that the mean errors converge to similar (slightly higher) results than when I used the random forestest regression function. However by using this bagging technique, it takes more tress for the convergence to happen and the mean absolute error is slightly higher (0.005), probably because random forests work to learn more from the important features whereas this bagging method uses all features at equal importance.
