# %%
# This code looks at using gradient boosting. 

# Boosing is learning from previous mistakes made. i.e. too far off with regression. 

# https://towardsdatascience.com/basic-ensemble-learning-random-forest-adaboost-gradient-boosting-step-by-step-explained-95d49d1e2725

# %% [markdown]
# Gradient boosting is better than Adaboost for our application as it is less senstitive to outliers.
#
# Adaboost minminses the exponential loss function that can make the algorithm sensitive to outliers
# In Adaboost, errors are identified by high-weight data points
#
# Gradient boost - any differentiable loss function can be utilised. This means that it is more robust.
# In Gradient Boosting, errors of existing weak learners are identified by gradients.
#
# Gradient boosting is better than random forest for this application. The key differences between the two algorithms are how the trees are built and how the results are combined.
#
# In gradient boosting, the trees are built one at a time. This means that the errors made in the tree before inform the next, or this can be thought of as introducing a weak learner to improve the shortcummings of the existing weak learner.
# When the results are combined in random forest, an average is taken. Gradient boosting combines the results along the way.
#
# Random forests peform better where there is a lot of noise in the data, as it reduces overfitting. Gradient boosting works well in this application as the data is unbalanced with a number of outliers.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_selection import SelectFromModel

# %%
nutrition = pd.read_pickle("/Users/oscarbond/Documents/GitHub/green-team-repo-2/Random forests/OB - Price/Nutrition_Full_Features.pkl")
#nutrition.drop(nutrition.columns[[]], axis=1, inplace=True) 

# removing the brand, and food type columns for data cleaning. 
nutrition
# Out:
#                                                    name   Food Group  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods
# ...                                                 ...          ...
# 1218                                    Plantain Fried    Vegetables
# 1219                                Romaine Lettuce Raw   Vegetables
# 1220                                       Palak Paneer   Vegetables
# 1221                                  Carrots Raw Salad   Vegetables
# 1222                                   Corn on the cob    Vegetables
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  \
# 0          1.70           260.0                      0.653846
# ...

# %%
nutrition = nutrition.dropna() # dropping NaN values. This ensures random forests can accept data. 
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
# ...

# %%
nutrition.dtypes # checking types of data
# Out:
# name                                        object
# Food Group                                  object
# Price (£)                                  float64
# Weight (GRAMS)                             float64
# Price per Weight (£/100Gram)               float64
# Carbon Group                                object
# Land use (m2/100g)                         float64
# GHG(kgco2eq/100g)                          float64
# Water use (L/100g)                         float64
# Acidifying emissions(kgSO2eq per 100g)     float64
# Eutr emissions  (kg PO43-eq per 100g)      float64
# Calories                                     int64
# Fat (g)                                    float64
# Protein (g)                                float64
# Carbohydrate (g)                           float64
# Sugars (g)                                 float64
# Fiber (g)                                  float64
# Saturated Fats (g)                         float64
# ...

# %%
X = nutrition.iloc[:, 11:].astype('float64').dropna() 
# pulling out the features data
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1        273.0     9.22         6.58             41.05        4.30        2.2
# 2        309.0     9.49         7.42             48.39        4.41        2.6
# 5        290.0    11.50         2.17             44.54       22.02        1.6
# 9        238.0     2.15        10.66             43.91        5.00        9.2
# 10       250.0     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218     241.0    10.16         1.66             40.60       19.10        2.9
# 1219      19.0     0.27         1.39              3.78        0.71        3.1
# 1220      96.0     6.84         5.23              4.32        1.89        1.2
# 1221     208.0    15.70         1.22             17.17       11.23        2.3
# 1222      67.0     1.22         2.28             14.30        4.43        2.0
#
# ...

# %%
y = nutrition.iloc[:, 4:5].astype('float64').dropna()
# pulling out the price data
y
# Out:
#       Price per Weight (£/100Gram)
# 1                         0.264550
# 2                         0.264550
# 5                         0.560000
# 9                         0.118750
# 10                        0.355556
# ...                            ...
# 1218                      1.058824
# 1219                      0.250000
# 1220                      0.750000
# 1221                      0.041000
# 1222                      0.171429
#
# [1042 rows x 1 columns]

# %%
# flattening the array for use in the random forest algorithm
y = np.ravel(y)
y
# Out:
# array([0.26455027, 0.26455027, 0.56      , ..., 0.75      , 0.041     ,
#        0.17142857])

# %%
from sklearn.model_selection import train_test_split
X_train_validation, X_test, y_train_validation, y_test = train_test_split(X,y,test_size=0.2)
# splitting the data into train and test data. 
#size =0.2 means 80% data is training data, 20% testing

# %%
# splitting the training data into validation and training data. 
X_train, X_validation, y_train, y_validation = train_test_split(X_train_validation,y_train_validation,test_size=0.01)

# %%
# Implementing GradientBoostingRegressor here
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor(n_estimators=120)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# checking the outputs 
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5681987852554012
# Mean Squared Error: 1.4739721212922419
# Root Mean Squared Error: 1.214072535432806

# %%
#automatically select features 
sel = SelectFromModel(model)
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=GradientBoostingRegressor(n_estimators=75))

# %%
#seeing which features are important 
#returns an array of trues when features are more important than mean 
# false when features are less important than mean importance 
sel.get_support()

# make a list and count selected features 

selected_feat = X_train.columns[(sel.get_support())]
#return the number of features selected by the random forest 
len(selected_feat)
# Out:
# 8

# %%
#get the name of feautures selected 
print(selected_feat)
# Out:
# Index(['Calories', 'Sugars (g)', 'Saturated Fats (g)', 'Calcium (mg)',
#        'Iron, Fe (mg)', 'PRAL score', 'Zinc, Zn (mg)', 'Copper, Cu (mg)'],
#       dtype='object')

# %%
Importances_idx = model.feature_importances_.argsort()

Features = X_train.columns[Importances_idx]
Importances = model.feature_importances_[Importances_idx]

# %%
Features = Features#[0:10]
Importances = Importances#[0:10]

# %%
plt.barh(Features, Importances)
# Out:
# <BarContainer object of 40 artists>

# %%
# checking the outputs 
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.943012177033446
# Mean Squared Error: 100.09664600610556
# Root Mean Squared Error: 10.004831133312823

# %%
np.mean(y)
np.std(y)
# Out:
# 7.118726897222426

# %%
Mean_Absolute_Error = []
Mean_Squared_Error = []
Root_Mean_Squared_Error = []

# %%
# creating a for loop to evaluate the hyperperameters of the model. Initally with n_estimators
# implementing the gradient boosting regression on the for loop
for i in range (1, 200, 5):
    from sklearn.ensemble import GradientBoostingRegressor
    model = GradientBoostingRegressor(n_estimators=i)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    
    Mean_Absolute_Error.append(mae)
    Mean_Squared_Error.append(mse)
    Root_Mean_Squared_Error.append(rmse)

# %%
# plotting the different metrics to see the effect of changing the number of trees
import matplotlib.pyplot as plt
n_trees = list(range(1, 200, 5))

f = plt.figure(1)

plt.subplot(311)
plt.plot(n_trees, Mean_Absolute_Error)
plt.ylabel('Mean Absolute Error')
plt.xlabel('Number of Trees')
plt.show()
plt.subplot(312)
plt.plot(n_trees, Mean_Squared_Error)
plt.ylabel('Mean_Squared_Error')
plt.xlabel('Number of Trees')
plt.show()
plt.subplot(313)
plt.plot(n_trees, Root_Mean_Squared_Error)
plt.ylabel('Root_Mean_Squared_Error')
plt.xlabel('Number of Trees')
plt.show()
