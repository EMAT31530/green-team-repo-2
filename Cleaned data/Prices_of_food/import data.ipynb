# %%
import numpy as np # numbers
import pandas as pd #data
import matplotlib.pyplot as plt #graphs

# %%
data = pd.read_csv(r'/Users/rachaelgreen/Desktop/Third_year_maths/Intro_to_ai/GitHub/ai-group-project-green-team/Prices_of_food/kosherfooddataset.csv', encoding='latin1')
data
# encoding='latin1' i used this to fix an error is that ok?
# Out:
#           ID                                               Name Manufacturer  \
# 0      12167                              Kansas City BBQ Sauce   Bull's-Eye
# 1      12166                         Steak Spice Montreal Style        Prima
# 2      12165                            The Best Meat Seasoning        Prima
# 3      12164                                  Chicken Seasoning        Prima
# 4      12163             Ramen Noodles Oriental Style Vegetable        Gefen
# ...      ...                                                ...          ...
# 10778      8                                 Apple Crumble Bars      Paskesz
# 10779      6                                       Brownie Bars      Paskesz
# 10780      4                                    Vanilla Cookies       Berman
# 10781      3  Softbite Chewy Chocolate Chocolate Chip Cookie...       Kemach
# 10782      2                Amor Di Pane Bread Sticks - Friable        Oscar
#
# ...
