# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import tensorflow
import keras

# %%
nutrition = pd.read_pickle("./Nutrition_Full_Features.pkl")
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#Data for features
X = nutrition.iloc[:, 11:]
y = nutrition.iloc[:, 4]

# %%
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
y
# Out:
# 1       0.264550
# 2       0.264550
# 5       0.560000
# 9       0.118750
# 10      0.355556
#           ...
# 1218    1.058824
# 1219    0.250000
# 1220    0.750000
# 1221    0.041000
# 1222    0.171429
# Name: Price per Weight (£/100Gram), Length: 1042, dtype: float64

# %%
# command/
#only normalising X not y. Is this right?
# norm_X = preprocessing.normalize(X, axis=0) #collum instead of row
# norm_X = pd.DataFrame(norm_X, columns = X.columns)
# X=norm_X
# X

# %%
y = np.ravel(y)
X = X.values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

# Feature Scaling/preprocessing - normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building model
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(16, activation = 'relu', input_dim = 40))

# Adding the second hidden layer
model.add(Dense(units = 8, activation = 'relu'))

#avoids overfitting
#https://keras.io/api/layers/regularization_layers/dropout/
model.add(keras.layers.Dropout(0.1))


# Adding the output layer

model.add(Dense(units = 1))


# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mse', metrics=['mae'])#metrics tracks values but doesn't decide with it

# Fitting the ANN to the Training set
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 2s 23ms/step - loss: 3.1461 - mae: 0.7229 - val_loss: 205.5857 - val_mae: 1.5612
# Epoch 2/100
# 59/59 [==============================] - 0s 3ms/step - loss: 1.8566 - mae: 0.5393 - val_loss: 205.1904 - val_mae: 1.5313
# Epoch 3/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.5100 - mae: 0.6156 - val_loss: 205.0101 - val_mae: 1.5098
# Epoch 4/100
# 59/59 [==============================] - 0s 3ms/step - loss: 2.5591 - mae: 0.5779 - val_loss: 204.9781 - val_mae: 1.4860
# Epoch 5/100
# 59/59 [==============================] - 0s 3ms/step - loss: 7.3094 - mae: 0.7319 - val_loss: 204.9480 - val_mae: 1.4630
# Epoch 6/100
# 59/59 [==============================] - 0s 3ms/step - loss: 2.2425 - mae: 0.5616 - val_loss: 204.7945 - val_mae: 1.4633
# Epoch 7/100
# 59/59 [==============================] - 0s 3ms/step - loss: 3.6498 - mae: 0.5575 - val_loss: 204.7796 - val_mae: 1.4508
# Epoch 8/100
# 59/59 [==============================] - 0s 3ms/step - loss: 1.
100
# 59/59 [==============================] - 0s 3ms/step - loss: 3.5962 - mae: 0.5036 - val_loss: 205.3594 - val_mae: 1.4102
# Epoch 100/100
# 59/59 [==============================] - 0s 3ms/step - loss: 1.0703 - mae: 0.3753 - val_loss: 205.4028 - val_mae: 1.4294

# %% [markdown]
# Parameters involved:
#     https://keras.io/api/models/model_training_apis/

# %%
#plot learning curves

#accuracy no idea what this is for
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mean absolute error')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['mae', 'Validation mae'], loc='upper left')
plt.show()

#loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_mae'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss'], loc='upper left')#, 'Validation Loss'
plt.show()

# %%
#model evaluation
score = model.evaluate(X_test, y_test)[1]
score2= model.evaluate(X_test, y_test)[0]
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6869 - mae: 0.5046
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6869 - mae: 0.5046

# %%
print('Accuracy without tuning: {}'.format(score))
print('Loss without tuning: {}'.format(score2))
# Out:
# Accuracy without tuning: 0.5045918822288513
# Loss without tuning: 0.6868728399276733

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                656
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# https://keras.io/api/models/sequential/
# The Sequential Class, provides a training and inference features on this model

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# %%
#Why are my errors all of a sudden so because of overfitting?
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5045918859883343
# Mean Squared Error: 0.6868729515039524
# Root Mean Squared Error: 0.8287779868601437

# %% [markdown]
# # Now Hyperparameter tuning

# %%
import kerastuner
from kerastuner import HyperModel

def build_model(hp):
    model = Sequential()
    for i in range(hp.Int('num_layers', 2, 20)): #2 to 20 hidden layers
        model.add(Dense(units=hp.Int('units_' + str(i),
                                            min_value=2,
                                            max_value=512, #no. of neurons tested is between 32 and 512
                                            step=4),
                                    activation= 'relu'))
    
    model.add(
        keras.layers.Dropout(
            hp.Float(
                    'dropout',
                    min_value=0.0001,
                    max_value=0.1,
                    step=0.01)
        )
    )

    # Adding the output layer
    model.add(Dense(units = 1, activation = 'linear'))


    model.compile(
        #optimizer='adam',
        optimizer = keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss = 'mean_squared_error',
        metrics = ['mae']
    )
    return model

# %%
tuner_rs = kerastuner.tuners.RandomSearch(
            build_model,
            objective='mae',
            max_trials=200,
            executions_per_trial=2, overwrite=True)

# %%
tuner_rs.search(X_train, y_train, epochs=100) #, verbose=0)
# Out:
# Trial 2 Complete [00h 01m 00s]
# mae: 0.828635573387146
#
# Best mae So Far: 0.8276926875114441
# Total elapsed time: 00h 01m 25s
#
# Search: Running Trial #3
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |5                 |20
# units_0           |318               |498
# units_1           |458               |354
# dropout           |0.0901            |0.0301
# learning_rate     |0.001             |0.01
# units_2           |110               |2
# units_3           |290               |2
# units_4           |362               |2
# units_5           |202               |2
# units_6           |226               |2
# units_7           |310               |2
# units_8           |218               |2
# units_9           |238               |2
# units_10          |146               |2
# units_11          |106               |2
# units_12          |118               |2
# units_13          |290               |2
# units_14          |94                |2
# units_15          |298               |2
# units_16          |302               |2
# units_17          |498               |2
# units_18          |378               |2
# units_19          |366               |2
#
# Epoch 1/100
# 27/27 [==============================] - 1s 3ms/step - loss: 141.1347 - mae: 1.3352
# Epoch 2/100
# 27/27 [==============================] - 0s 4ms/step - loss: 10.3032 - mae: 0.5425
# 27/27 [==============================] - 0s 4ms/step - loss: 49.2436 - mae: 1.1099
# Epoch 96/100
# 27/27 [==============================] - 0s 4ms/step - loss: 23.3439 - mae: 0.9591
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 76.9433 - mae: 0.8489
# Epoch 98/100
# 27/27 [==============================] - 0s 4ms/step - loss: 9.6198 - mae: 0.6479
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 48.1296 - mae: 0.7740
# Epoch 100/100
# 27/27 [==============================] - 0s 4ms/step - loss: 8.6919 - mae: 0.5865
# Epoch 1/100
# 27/27 [==============================] - 1s 3ms/step - loss: 12.0893 - mae: 0.6798
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 33.8444 - mae: 0.7992
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 17.8346 - mae: 0.5753
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 45.5047 - mae: 0.8839
# Epoch 5/100
# 27/27 [==============================] - 0s 4ms/step - loss: 25.9728 - mae: 0.5971
# Epoch 6/100
# 27/27 [==============================] - 0s 4ms/step - loss: 135.9172 - mae: 1.4457
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 20.6440 - mae: 0.6588
# Epoch 8/100
# 27/27 [==============================] - 0s 4ms/step - loss: 28.6905 - mae: 0.6961
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 19.7849 - mae: 0.5841
# Epoch 10/100
# 27/27 [==============================] - 0s 4ms/step - loss: 74.1337 - mae: 1.1271
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 167.1799 - mae: 1.3008
# Epoch 12/100
# 27/27 [==============================] - 0s 4ms/step - loss: 13.5813 - mae: 0.4892
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 117.3262 - mae: 1.5539
# Epoch 14/100
# 27/27 [==============================] - 0s 4ms/step - loss: 19.4742 - mae: 0.6233
# Epoch 15/100
# 27/27 [==============================] - 0s 4ms/step - loss: 26.9942 - mae: 0.6769
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 52.4654 - mae: 0.7619
# Epoch 17/100
# 27/27 [==============================] - 0s 4ms/step - loss: 32.9210 - mae: 0.7030
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 221.3492 - mae: 1.6266
# Epoch 19/100
# 27/27 [==============================] - 0s 4ms/step - loss: 23.9148 - mae: 0.5786
# Epoch 20/100
# 27/27 [==============================] - 0s 5ms/step - loss: 47.3160 - mae: 0.8156
# Epoch 21/100
# 27/27 [==============================] - 0s 4ms/step - loss: 115.9950 - mae: 1.2578
# Epoch 22/100
# 27/27 [==============================] - 0s 4ms/step - loss: 26.2280 - mae: 0.7178
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 37.7307 - mae: 0.7699
# Epoch 24/100
# 27/27 [==============================] - 0s 4ms/step - loss: 21.9120 - mae: 0.6030
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 74.3708 - mae: 1.1398
# Epoch 26/100
# 27/27 [==============================] - 0s 3ms/step - loss: 69.4900 - mae: 1.1475
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 87.0855 - mae: 1.1968
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 58.7030 - mae: 0.8797
# Epoch 29/100
# 27/27 [==============================] - 0s 3ms/step - loss: 12.3724 - mae: 0.5731
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 167.6825 - mae: 1.6650
# Epoch 31/100
# 27/27 [==============================] - 0s 3ms/step - loss: 120.4735 - mae: 1.1622
# Epoch 32/100
# 27/27 [==============================] - 0s 3ms/step - loss: 94.3411 - mae: 0.9261
# Epoch 33/100
# 27/27 [==============================] - 0s 4ms/step - loss: 33.5182 - mae: 0.6770
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 20.1625 - mae: 0.6030
# Epoch 35/100
# 27/27 [==============================] - 0s 4ms/step - loss: 43.4291 - mae: 0.7691
# Epoch 36/100
# 27/27 [==============================] - 0s 3ms/step - loss: 47.8326 - mae: 0.7079
# Epoch 37/100
# 27/27 [==============================] - 0s 3ms/step - loss: 49.6296 - mae: 0.8313
# Epoch 38/100
# 27/27 [==============================] - 0s 3ms/step - loss: 29.6420 - mae: 0.7110
# Epoch 39/100
# 27/27 [==============================] - 0s 3ms/step - loss: 67.8020 - mae: 0.8753
# Epoch 40/100
# 27/27 [==============================] - 0s 3ms/step - loss: 13.9372 - mae: 0.5799
# Epoch 41/100
# 27/27 [==============================] - 0s 4ms/step - loss: 9.1226 - mae: 0.7678
# Epoch 42/100
# 27/27 [==============================] - 0s 3ms/step - loss: 41.9630 - mae: 0.7663
# Epoch 43/100
# 27/27 [==============================] - 0s 4ms/step - loss: 65.5491 - mae: 1.0538
# Epoch 44/100
# 27/27 [==============================] - 0s 4ms/step - loss: 63.0645 - mae: 1.4354
# Epoch 45/100
# 27/27 [==============================] - 0s 3ms/step - loss: 35.9412 - mae: 0.7620
# Epoch 46/100
# 27/27 [==============================] - 0s 5ms/step - loss: 168.1683 - mae: 1.3530
# Epoch 47/100
# 27/27 [==============================] - 0s 3ms/step - loss: 31.2626 - mae: 0.7122
# Epoch 48/100
# 12/27 [============>.................] - ETA: 0s - loss: 118.0367 - mae: 1.2016

# %%
#collect best hyperparameters to rebuild model
best_model = tuner_rs.get_best_hyperparameters()[0]
model = tuner_rs.hypermodel.build(best_model)

# %%
# Training the Model
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3, verbose = 0)

# %%
model.summary()

# %%
#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
# get new predicted values with Hyperparameters
y_best_model_pred = model.predict(X_test)

# %%
# plot predicted values against test values
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_best_model_pred, color = 'blue', label = 'HP Predicted data')
plt.title('HP Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
# checking the output metrics
from sklearn import metrics

y_hp_pred=y_best_model_pred

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_hp_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_hp_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hp_pred)))

y_mean = np.mean(y_hp_pred)
y_std = np.std(y_hp_pred)
print('Output Standard Deviation:', y_std)
print('Output Mean:', y_mean)

# %%
tuner_rs.results_summary()
