# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import tensorflow
import keras

# %%
nutrition = pd.read_pickle("./Nutrition_Full_Features.pkl")
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#Data for features
X = nutrition.iloc[:, 11:]
y = nutrition.iloc[:, 4]

# %%
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
y
# Out:
# 1       0.264550
# 2       0.264550
# 5       0.560000
# 9       0.118750
# 10      0.355556
#           ...
# 1218    1.058824
# 1219    0.250000
# 1220    0.750000
# 1221    0.041000
# 1222    0.171429
# Name: Price per Weight (£/100Gram), Length: 1042, dtype: float64

# %%
# command/
#only normalising X not y. Is this right?
# norm_X = preprocessing.normalize(X, axis=0) #collum instead of row
# norm_X = pd.DataFrame(norm_X, columns = X.columns)
# X=norm_X
# X

# %%
y = np.ravel(y)
X = X.values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

# Feature Scaling/preprocessing - normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building model
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(16, activation = 'relu', input_dim = 40))

# Adding the second hidden layer
model.add(Dense(units = 8, activation = 'relu'))

#avoids overfitting
#https://keras.io/api/layers/regularization_layers/dropout/
model.add(keras.layers.Dropout(0.1))


# Adding the output layer

model.add(Dense(units = 1))


# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mse', metrics=['mae'])#metrics tracks values but doesn't decide with it

# Fitting the ANN to the Training set
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 1s 13ms/step - loss: 2.4975 - mae: 0.8177 - val_loss: 206.3189 - val_mae: 1.5758
# Epoch 2/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.7882 - mae: 0.6334 - val_loss: 205.9074 - val_mae: 1.5371
# Epoch 3/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.6011 - mae: 0.5712 - val_loss: 205.6818 - val_mae: 1.5101
# Epoch 4/100
# 59/59 [==============================] - 0s 1ms/step - loss: 2.4282 - mae: 0.5521 - val_loss: 205.4705 - val_mae: 1.5004
# Epoch 5/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.6414 - mae: 0.4940 - val_loss: 205.2424 - val_mae: 1.4785
# Epoch 6/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.8296 - mae: 0.5415 - val_loss: 205.1429 - val_mae: 1.4670
# Epoch 7/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.1906 - mae: 0.5328 - val_loss: 205.0905 - val_mae: 1.4575
# Epoch 8/100
# 59/59 [==============================] - 0s 1ms/step - loss: 0.7690 - mae: 0.4492 - val_loss: 204.9922 - val_mae: 1.4596
# Epoch 9/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.5738 - mae: 0.4995 - val_loss: 204.9188 - val_mae: 1.4599
# Epoch 10/100
# 59/59 [==============================] - 0s 1ms/step - loss: 2
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mean absolute error')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['mae', 'Validation mae'], loc='upper left')
plt.show()

#loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_mae'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss'], loc='upper left')#, 'Validation Loss'
plt.show()

# %%
#model evaluation
score = model.evaluate(X_test, y_test)[1]
score2= model.evaluate(X_test, y_test)[0]
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9784 - mae: 0.5225
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9784 - mae: 0.5225

# %%
print('Accuracy without tuning: {}'.format(score))
print('Loss without tuning: {}'.format(score2))
# Out:
# Accuracy without tuning: 0.5224558115005493
# Loss without tuning: 0.9784272313117981

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                656
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# https://keras.io/api/models/sequential/
# The Sequential Class, provides a training and inference features on this model

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# %%
#Why are my errors all of a sudden so because of overfitting?
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5224558426528503
# Mean Squared Error: 0.9784272877391061
# Root Mean Squared Error: 0.9891548350683558

# %% [markdown]
# # Now Hyperparameter tuning

# %%
import kerastuner
from kerastuner import HyperModel

def build_model(hp):
    model = Sequential()
    for i in range(hp.Int('num_layers', 2, 20)): #2 to 20 hidden layers
        model.add(Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512, #no. of neurons tested is between 32 and 512
                                            step=32),
                               activation= hp.Choice('dense_activation', 
                                                     values=['relu', 'tanh','sigmoid'])))
    
    model.add(
        keras.layers.Dropout(
            hp.Float(
                    'dropout',
                    min_value=0.0001,
                    max_value=0.1,
                    step=0.01)
        )
    )

    # Adding the output layer
    model.add(Dense(units = 1, activation = 'linear'))


    model.compile(
        #optimizer='adam',
        optimizer = hp.Choice('dense_optimizer',
                values=['adam','SGD','rmsprop','adadelta'] ),
        loss = 'mean_squared_error',
        metrics = ['mae']
    )
    return model

# %%
tuner_rs = kerastuner.tuners.RandomSearch(
            build_model,
            objective='mae',
            max_trials=200,
            executions_per_trial=2, overwrite=True)

# %%
tuner_rs.search(X_train, y_train, epochs=100) #, verbose=0)
# Out:
# Trial 12 Complete [00h 00m 40s]
# mae: 0.9557422697544098
#
# Best mae So Far: 0.40792088210582733
# Total elapsed time: 00h 05m 58s
#
# Search: Running Trial #13
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |6                 |7
# units_0           |128               |128
# dense_activation  |relu              |relu
# units_1           |96                |352
# dropout           |0.0701            |0.0501
# dense_optimizer   |rmsprop           |adam
# units_2           |160               |32
# units_3           |320               |32
# units_4           |224               |32
# units_5           |288               |32
# units_6           |288               |32
# units_7           |320               |None
# units_8           |128               |None
# units_9           |320               |None
# units_10          |448               |None
# units_11          |352               |None
# units_12          |352               |None
# units_13          |64                |None
# units_14          |96                |None
# units_15          |224               |None
# units_16          |448               |None
# units_17          |32                |None
# units_18          |416               |None
#
# Epoch 1/100
# 27/27 [==============================] - 1s 3ms/step - loss: 53.4729 - mae: 0.8698
# Epoch 2/100
# 27/27 [==============================] - 0s 4ms/step - loss: 86.5525 - mae: 0.9548
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 15.8617 - mae: 0.5553
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 119.1708 - mae: 1.0959
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 23.8554 - mae: 0.5858
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 24.9328 - mae: 0.5314
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 23.0648 - mae: 0.6007
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 91.7855 - mae: 0.9940
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 21.6010 - mae: 0.6470
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 89.0217 - mae: 1.0126
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 45.5404 - mae: 0.7567
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 15.4991 - mae: 0.6004
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 14.1650 - mae: 0.5641
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 13.2766 - mae: 0.5026
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 120.2595 - mae: 1.2243
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 103.7008 - mae: 1.1537
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 50.2253 - mae: 0.7086
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 9.5399 - mae: 0.4584
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 50.3362 - mae: 0.8925
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 20.3363 - mae: 0.5631
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 36.5183 - mae: 0.7681
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 10.6137 - mae: 0.4881
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 20.2725 - mae: 0.4906
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 4.1900 - mae: 0.5060
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/step - loss: 42.8548 - mae: 0.8505
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 14.7234 - mae: 0.6280
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 8.7133 - mae: 0.5274
# Epoch 28/100
# 27/27 [==============================] - 0s 6ms/step - loss: 10.9919 - mae: 0.5784
# Epoch 29/100
# 27/27 [==============================] - 0s 4ms/step - loss: 3.6551 - mae: 0.4983
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 9.2403 - mae: 0.4733
# Epoch 31/100
# 27/27 [==============================] - 0s 3ms/step - loss: 4.5829 - mae: 0.4322
# Epoch 32/100
# 27/27 [==============================] - 0s 4ms/step - loss: 1.4180 - mae: 0.4487
# Epoch 33/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3.4188 - mae: 0.5374
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 4.5185 - mae: 0.5270
# Epoch 35/100
# 27/27 [==============================] - 0s 4ms/step - loss: 5.2314 - mae: 0.5217
# Epoch 36/100
# 27/27 [==============================] - 0s 3ms/step - loss: 21.4063 - mae: 0.5951
# Epoch 37/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3.9643 - mae: 0.4962
# Epoch 38/100
# 27/27 [==============================] - 0s 3ms/step - loss: 8.1809 - mae: 0.5285
# Epoch 39/100
# 27/27 [==============================] - 0s 3ms/step - loss: 3.1685 - mae: 0.5611
# Epoch 40/100
# 27/27 [==============================] - 0s 3ms/step - loss: 11.7650 - mae: 0.5307
# Epoch 41/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.1698 - mae: 0.3697
# Epoch 42/100
# 27/27 [==============================] - 0s 4ms/step - loss: 20.7203 - mae: 0.6875
# Epoch 43/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3180 - mae: 0.3581
# Epoch 44/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.8687 - mae: 0.4556
# Epoch 45/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.1742 - mae: 0.4613
# Epoch 46/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.9841 - mae: 0.3826
# Epoch 47/100
# 27/27 [==============================] - 0s 3ms/step - loss: 5.8909 - mae: 0.4439
# Epoch 48/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6155 - mae: 0.3786
# Epoch 49/100
# 27/27 [==============================] - 0s 4ms/step - loss: 9.2603 - mae: 0.4881
# Epoch 50/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.8992 - mae: 0.4198
# Epoch 51/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.4810 - mae: 0.3282
# Epoch 52/100
# 27/27 [==============================] - 0s 3ms/step - loss: 4.6085 - mae: 0.4481
# Epoch 53/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4944 - mae: 0.3407
# Epoch 54/100
# 27/27 [==============================] - 0s 3ms/step - loss: 9.7725 - mae: 0.4467
# Epoch 55/100
# 27/27 [==============================] - 0s 3ms/step - loss: 1.0676 - mae: 0.3792
# Epoch 56/100
# 27/27 [==============================] - 0s 4ms/step - loss: 29.3639 - mae: 0.6628
# Epoch 57/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2406 - mae: 0.3019
# Epoch 58/100
# 27/27 [==============================] - 0s 3ms/step - loss: 17.7816 - mae: 0.4347
# Epoch 59/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8855 - mae: 0.3770
# Epoch 60/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.8619 - mae: 0.3363
# Epoch 61/100
# 27/27 [==============================] - 0s 3ms/step - loss: 8.0567 - mae: 0.4396
# Epoch 62/100
# 27/27 [==============================] - 0s 4ms/step - loss: 5.5333 - mae: 0.3569
# Epoch 63/100
# 27/27 [==============================] - 0s 4ms/step - loss: 4.0133 - mae: 0.3359
# Epoch 64/100
# 27/27 [==============================] - 0s 3ms/step - loss: 2.3521 - mae: 0.3263
# Epoch 65/100
#  1/27 [>.............................] - ETA: 0s - loss: 0.0815 - mae: 0.2226

# %%
#collect best hyperparameters to rebuild model
best_model = tuner_rs.get_best_hyperparameters()[0]
model = tuner_rs.hypermodel.build(best_model)

# %%
# Training the Model
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3, verbose = 0)

# %%
model.summary()

# %%
#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
# get new predicted values with Hyperparameters
y_best_model_pred = model.predict(X_test)

# %%
# plot predicted values against test values
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_best_model_pred, color = 'blue', label = 'HP Predicted data')
plt.title('HP Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
# checking the output metrics
from sklearn import metrics

y_hp_pred=y_best_model_pred

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_hp_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_hp_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hp_pred)))

y_mean = np.mean(y_hp_pred)
y_std = np.std(y_hp_pred)
print('Output Standard Deviation:', y_std)
print('Output Mean:', y_mean)

# %%
tuner_rs.results_summary()
