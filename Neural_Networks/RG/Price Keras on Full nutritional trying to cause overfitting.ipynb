# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import tensorflow
import keras

# %%
nutrition = pd.read_pickle("./Nutrition_Full_Features.pkl")
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#Data for features
X = nutrition.iloc[:, 11:]
y = nutrition.iloc[:, 4]

# %%
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
y
# Out:
# 1       0.264550
# 2       0.264550
# 5       0.560000
# 9       0.118750
# 10      0.355556
#           ...
# 1218    1.058824
# 1219    0.250000
# 1220    0.750000
# 1221    0.041000
# 1222    0.171429
# Name: Price per Weight (£/100Gram), Length: 1042, dtype: float64

# %%
# command/
#only normalising X not y. Is this right?
# norm_X = preprocessing.normalize(X, axis=0) #collum instead of row
# norm_X = pd.DataFrame(norm_X, columns = X.columns)
# X=norm_X
# X

# %%
y = np.ravel(y)
X = X.values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %% [markdown]
# Want to overfit in order to make model work then can underfit after

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

# Feature Scaling/preprocessing - normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building model
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(512, activation = 'relu', input_dim = 40))

# Adding the second hidden layer
model.add(Dense(units = 256, activation = 'relu'))

# Adding the more hidden layer
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 16, activation = 'relu'))

model.add(Dense(units = 8, activation = 'relu'))

#avoids overfitting, havent got overfitting
#https://keras.io/api/layers/regularization_layers/dropout/
#model.add(keras.layers.Dropout(0.1))


# Adding the output layer

model.add(Dense(units = 1))


# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mse', metrics=['accuracy'])

# Fitting the ANN to the Training set, Increasing batch size to increase overfitting
history = model.fit(X_train, y_train, batch_size = 120, epochs = 100, validation_split=0.3)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 60ms/step - loss: 4.8405 - accuracy: 0.0000e+00 - val_loss: 206.8477 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 13ms/step - loss: 2.2269 - accuracy: 0.0000e+00 - val_loss: 206.6056 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.3642 - accuracy: 0.0000e+00 - val_loss: 206.1275 - val_accuracy: 0.0040
# Epoch 4/100
# 5/5 [==============================] - 0s 16ms/step - loss: 2.
100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1827 - accuracy: 0.0159 - val_loss: 206.0213 - val_accuracy: 0.0160
# Epoch 63/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1713 - accuracy: 0.0107 - val_loss: 205.6941 - val_accuracy: 0.0160
# Epoch 64/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1353 - accuracy: 0.0096 - val_loss: 205.7968 - val_accuracy: 0.0160
# Epoch 65/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2244 - accuracy: 0.0157 - val_loss: 206.0313 - val_accuracy: 0.0160
# Epoch 66/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1596 - accuracy: 0.0125 - val_loss: 205.9497 - val_accuracy: 0.0160
# Epoch 67/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1326 - accuracy: 0.0084 - val_loss: 205.8886 - val_accuracy: 0.0160
# Epoch 68/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1308 - accuracy: 0.0081 - val_loss: 205.8145 - val_accuracy: 0.0160
# Epoch 69/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1152 - accuracy: 0.0059 - val_loss: 205.7803 - val_accuracy: 0.0120
# Epoch 70/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1013 - accuracy: 0.0106 - val_loss: 205.7916 - val_accuracy: 0.0160
# Epoch 71/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1296 - accuracy: 0.0127 - val_loss: 205.7975 - val_accuracy: 0.0160
# Epoch 72/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1287 - accuracy: 0.0052 - val_loss: 205.6803 - val_accuracy: 0.0160
# Epoch 73/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1005 - accuracy: 0.0078 - val_loss: 205.6260 - val_accuracy: 0.0160
# Epoch 74/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0883 - accuracy: 0.0083 - val_loss: 205.6232 - val_accuracy: 0.0160
# Epoch 75/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.1138 - accuracy: 0.0138 - val_loss: 205.5299 - val_accuracy: 0.0120
# Epoch 76/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.1121 - accuracy: 0.0064 - val_loss: 205.5612 - val_accuracy: 0.0160
# Epoch 77/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0809 - accuracy: 0.0112 - val_loss: 205.5815 - val_accuracy: 0.0160
# Epoch 78/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0831 - accuracy: 0.0079 - val_loss: 205.5367 - val_accuracy: 0.0160
# Epoch 79/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0948 - accuracy: 0.0106 - val_loss: 205.4900 - val_accuracy: 0.0120
# Epoch 80/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0885 - accuracy: 0.0160 - val_loss: 205.5255 - val_accuracy: 0.0160
# Epoch 81/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0895 - accuracy: 0.0143 - val_loss: 205.4886 - val_accuracy: 0.0120
# Epoch 82/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0924 - accuracy: 0.0118 - val_loss: 205.5259 - val_accuracy: 0.0160
# Epoch 83/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0973 - accuracy: 0.0153 - val_loss: 205.5370 - val_accuracy: 0.0120
# Epoch 84/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0806 - accuracy: 0.0173 - val_loss: 205.6365 - val_accuracy: 0.0120
# Epoch 85/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0880 - accuracy: 0.0108 - val_loss: 205.5969 - val_accuracy: 0.0120
# Epoch 86/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1044 - accuracy: 0.0160 - val_loss: 205.5633 - val_accuracy: 0.0120
# Epoch 87/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0863 - accuracy: 0.0141 - val_loss: 205.5919 - val_accuracy: 0.0120
# Epoch 88/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0774 - accuracy: 0.0112 - val_loss: 205.5352 - val_accuracy: 0.0120
# Epoch 89/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1001 - accuracy: 0.0181 - val_loss: 205.5801 - val_accuracy: 0.0120
# Epoch 90/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0652 - accuracy: 0.0142 - val_loss: 205.5611 - val_accuracy: 0.0120
# Epoch 91/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0861 - accuracy: 0.0100 - val_loss: 205.6095 - val_accuracy: 0.0120
# Epoch 92/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0952 - accuracy: 0.0131 - val_loss: 205.5732 - val_accuracy: 0.0120
# Epoch 93/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0611 - accuracy: 0.0156 - val_loss: 205.5929 - val_accuracy: 0.0120
# Epoch 94/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0842 - accuracy: 0.0129 - val_loss: 205.5834 - val_accuracy: 0.0120
# Epoch 95/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0657 - accuracy: 0.0083 - val_loss: 205.5488 - val_accuracy: 0.0120
# Epoch 96/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0849 - accuracy: 0.0121 - val_loss: 205.5857 - val_accuracy: 0.0120
# Epoch 97/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0658 - accuracy: 0.0157 - val_loss: 205.4630 - val_accuracy: 0.0120
# Epoch 98/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0830 - accuracy: 0.0120 - val_loss: 205.5181 - val_accuracy: 0.0120
# Epoch 99/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0760 - accuracy: 0.0156 - val_loss: 205.5388 - val_accuracy: 0.0120
# Epoch 100/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0647 - accuracy: 0.0194 - val_loss: 205.5869 - val_accuracy: 0.0120

# %% [markdown]
# Parameters involved:
#     https://keras.io/api/models/model_training_apis/

# %%
#plot learning curves

#accuracy no idea what this is for
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Accuracy', 'Validation Accuracy'], loc='upper left')
plt.show()

#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['Loss', 'Validation Loss'], loc='upper left')
plt.legend(['Loss'], loc='upper left')
plt.show()

# %%
#model evaluation
score = model.evaluate(X_test, y_test)[1]
score2= model.evaluate(X_test, y_test)[0]
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7950 - accuracy: 0.0191
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7950 - accuracy: 0.0191

# %%
print('Accuracy without tuning: {}'.format(score))
print('Loss without tuning: {}'.format(score2))
# Out:
# Accuracy without tuning: 0.019138755276799202
# Loss without tuning: 0.7949560284614563

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 328
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 489
# Trainable params: 489
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# https://keras.io/api/models/sequential/
# The Sequential Class, provides a training and inference features on this model

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# %%
#Why are my errors all of a sudden so because of overfitting?
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5181566432336027
# Mean Squared Error: 0.7949560295687614
# Root Mean Squared Error: 0.8916030672719567

# %% [markdown]
# # Now Hyperparameter tuning

# %%
import kerastuner
from kerastuner import HyperModel

def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid']),#,'softmax']),
        input_dim = 40
        )
             
    )

    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid'])#,'softmax'])
        )
             
    )
    
    model.add(
        keras.layers.Dropout(
            hp.Float(
                    'dropout',
                    min_value=0.0,
                    max_value=0.1,
                    step=0.01)
        )
    )

    # Adding the output layer
    model.add(Dense(units = 1))


    model.compile(
        #optimizer='adam',
        optimizer = hp.Choice('dense_optimizer',
                values=['adam','SGD','rmsprop','adadelta'] ),
        loss = 'mean_squared_error',
        metrics = ['accuracy']
    )
    return model

# %%
tuner_rs = kerastuner.tuners.RandomSearch(
            build_model,
            objective='loss',
            max_trials=20,
            executions_per_trial=2, overwrite=True)

# %%
tuner_rs.search(X_train, y_train, epochs=50) #, verbose=0)
# Out:
# Trial 20 Complete [00h 00m 04s]
# loss: 62.49416542053223
#
# Best loss So Far: 56.52271842956543
# Total elapsed time: 00h 01m 18s
# INFO:tensorflow:Oracle triggered exit

# %%
#best_model = tuner_rs.get_best_models(num_models=1)
#best_model = tuner_rs.get_best_models(num_models=1)[0]
#mse_rs = best_model.evaluate(X_test, y_test)[1]

# %%
#loss, mse = best_model.evaluate(X_test, y_test)

# %%
#collect best hyperparameters to rebuild model
best_model = tuner_rs.get_best_hyperparameters()[0]
model = tuner_rs.hypermodel.build(best_model)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                820
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dropout (Dropout)            (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,261
# Trainable params: 1,261
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the Model
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3, verbose = 0)

# %%
#loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
# get new predicted values with Hyperparameters
y_best_model_pred = model.predict(X_test)

# %%
# plot predicted values against test values
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_best_model_pred, color = 'blue', label = 'HP Predicted data')
plt.title('HP Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
# checking the output metrics
from sklearn import metrics

y_hp_pred=y_best_model_pred

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_hp_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_hp_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hp_pred)))

y_mean = np.mean(y_hp_pred)
y_std = np.std(y_hp_pred)
print('Output Standard Deviation:', y_std)
print('Output Mean:', y_mean)
# Out:
# Mean Absolute Error: 0.671813158786838
# Mean Squared Error: 1.3151617513897844
# Root Mean Squared Error: 1.146805018906782
# Output Standard Deviation: 0.9451277
# Output Mean: 0.5614292

# %%
tuner_rs.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='loss', direction='min')
# Trial summary
# Hyperparameters:
# units: 20
# dense_activation: tanh
# dropout: 0.02
# dense_optimizer: SGD
# Score: 56.52271842956543
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: tanh
# dropout: 0.01
# dense_optimizer: SGD
# Score: 57.40688896179199
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: tanh
# dropout: 0.05
# dense_optimizer: SGD
# Score: 57.98969268798828
# Trial summary
# Hyperparameters:
# units: 28
# dense_activation: relu
# dropout: 0.1
# dense_optimizer: rmsprop
# Score: 61.25052261352539
# Trial summary
# Hyperparameters:
# units: 32
# dense_activation: tanh
# dropout: 0.06
# dense_optimizer: rmsprop
# Score: 61.26289176940918
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: tanh
# dropout: 0.08
# dense_optimizer: adam
# Score: 61.409929275512695
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: relu
# dropout: 0.07
# dense_optimizer: rmsprop
# Score: 61.85635948181152
# Trial summary
# Hyperparameters:
# units: 28
# dense_activation: sigmoid
# dropout: 0.06
# dense_optimizer: adam
# Score: 62.42808151245117
# Trial summary
# Hyperparameters:
# units: 20
# dense_activation: sigmoid
# dropout: 0.02
# dense_optimizer: adam
# Score: 62.49416542053223
# Trial summary
# Hyperparameters:
# units: 32
# dense_activation: sigmoid
# dropout: 0.08
# dense_optimizer: rmsprop
# Score: 62.52206230163574
