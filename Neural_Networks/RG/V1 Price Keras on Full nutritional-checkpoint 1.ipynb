# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import tensorflow
import keras

# %%
nutrition = pd.read_pickle("./Nutrition_Full_Features.pkl")
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#Data for features
X = nutrition.iloc[:, 11:]
y = nutrition.iloc[:, 4]

# %%
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
y
# Out:
# 1       0.264550
# 2       0.264550
# 5       0.560000
# 9       0.118750
# 10      0.355556
#           ...
# 1218    1.058824
# 1219    0.250000
# 1220    0.750000
# 1221    0.041000
# 1222    0.171429
# Name: Price per Weight (£/100Gram), Length: 1042, dtype: float64

# %%
# command/
#only normalising X not y. Is this right?
# norm_X = preprocessing.normalize(X, axis=0) #collum instead of row
# norm_X = pd.DataFrame(norm_X, columns = X.columns)
# X=norm_X
# X

# %%
y = np.ravel(y)
X = X.values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

# Feature Scaling/preprocessing - normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building model
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(16, activation = 'relu', input_dim = 40))

# Adding the second hidden layer
model.add(Dense(units = 8, activation = 'relu'))

#avoids overfitting
#https://keras.io/api/layers/regularization_layers/dropout/
model.add(keras.layers.Dropout(0.1))


# Adding the output layer

model.add(Dense(units = 1))


# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mse', metrics=['accuracy'])#metrics tracks values but doesn't decide with it

# Fitting the ANN to the Training set
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 1s 11ms/step - loss: 2.6379 - accuracy: 0.0031 - val_loss: 205.3625 - val_accuracy: 0.0040
# Epoch 2/100
# 59/59 [==============================] - 0s 2ms/step - loss: 3
100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.5803 - accuracy: 0.0064 - val_loss: 205.1608 - val_accuracy: 0.0080
# Epoch 87/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.0169 - val_loss: 205.1762 - val_accuracy: 0.0080
# Epoch 88/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.9438 - accuracy: 0.0069 - val_loss: 205.2247 - val_accuracy: 0.0040
# Epoch 89/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.4786 - accuracy: 0.0147 - val_loss: 205.1633 - val_accuracy: 0.0080
# Epoch 90/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5742 - accuracy: 0.0171 - val_loss: 205.1783 - val_accuracy: 0.0040
# Epoch 91/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.9175 - accuracy: 0.0128 - val_loss: 205.1920 - val_accuracy: 0.0040
# Epoch 92/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.2065 - accuracy: 0.0135 - val_loss: 205.1974 - val_accuracy: 0.0040
# Epoch 93/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.4243 - accuracy: 0.0124 - val_loss: 205.2646 - val_accuracy: 0.0040
# Epoch 94/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.6554 - accuracy: 0.0120 - val_loss: 205.2231 - val_accuracy: 0.0040
# Epoch 95/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.2102 - accuracy: 0.0097 - val_loss: 205.2051 - val_accuracy: 0.0040
# Epoch 96/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.2923 - accuracy: 0.0159 - val_loss: 205.2910 - val_accuracy: 0.0080
# Epoch 97/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6689 - accuracy: 0.0156 - val_loss: 205.2309 - val_accuracy: 0.0040
# Epoch 98/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.0099 - val_loss: 205.2857 - val_accuracy: 0.0040
# Epoch 99/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.0594 - accuracy: 0.0145 - val_loss: 205.2974 - val_accuracy: 0.0040
# Epoch 100/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.0527 - accuracy: 0.0194 - val_loss: 205.2171 - val_accuracy: 0.0040

# %% [markdown]
# Parameters involved:
#     https://keras.io/api/models/model_training_apis/

# %%
#plot learning curves

#accuracy no idea what this is for
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'Validation accuracy'], loc='upper left')
plt.show()

#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss'], loc='upper left')#, 'Validation Loss'
plt.show()

# %%
#model evaluation
score = model.evaluate(X_test, y_test)[1]
score2= model.evaluate(X_test, y_test)[0]
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6479 - accuracy: 0.0144
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6479 - accuracy: 0.0144

# %%
print('Accuracy without tuning: {}'.format(score))
print('Loss without tuning: {}'.format(score2))
# Out:
# Accuracy without tuning: 0.014354066923260689
# Loss without tuning: 0.6478997468948364

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                656
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# https://keras.io/api/models/sequential/
# The Sequential Class, provides a training and inference features on this model

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# %%
#Why are my errors all of a sudden so because of overfitting?
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.48475897530961326
# Mean Squared Error: 0.6478996602952629
# Root Mean Squared Error: 0.8049221454869179

# %% [markdown]
# # Now Hyperparameter tuning

# %%
import kerastuner
from kerastuner import HyperModel

def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid']),#,'softmax']),
        input_dim = 40
        )
             
    )

    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid'])#,'softmax'])
        )
             
    )
    
    model.add(
        keras.layers.Dropout(
            hp.Float(
                    'dropout',
                    min_value=0.01,
                    max_value=0.1,
                    step=0.01)
        )
    )

    # Adding the output layer
    model.add(Dense(units = 1))


    model.compile(
        #optimizer='adam',
        optimizer = hp.Choice('dense_optimizer',
                values=['adam']),#'SGD','rmsprop','adadelta'] ),
        loss = 'mean_squared_error',
        metrics = ['accuracy']
    )
    return model

# %%
tuner_rs = kerastuner.tuners.RandomSearch(
            build_model,
            objective='loss',
            max_trials=4,
            executions_per_trial=2, overwrite=True)

# %%
tuner_rs.search(X_train, y_train, epochs=50) #, verbose=0)
# Out:
# Trial 4 Complete [00h 00m 05s]
# loss: 59.481157302856445
#
# Best loss So Far: 59.481157302856445
# Total elapsed time: 00h 00m 21s
# INFO:tensorflow:Oracle triggered exit

# %%
#best_model = tuner_rs.get_best_models(num_models=1)
#best_model = tuner_rs.get_best_models(num_models=1)[0]
#mse_rs = best_model.evaluate(X_test, y_test)[1]

# %%
#loss, mse = best_model.evaluate(X_test, y_test)

# %%
#collect best hyperparameters to rebuild model
best_model = tuner_rs.get_best_hyperparameters()[0]
model = tuner_rs.hypermodel.build(best_model)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 12)                492
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                156
# _________________________________________________________________
# dropout (Dropout)            (None, 12)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 13
# =================================================================
# Total params: 661
# Trainable params: 661
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the Model
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3, verbose = 0)

# %%
#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
# get new predicted values with Hyperparameters
y_best_model_pred = model.predict(X_test)

# %%
# plot predicted values against test values
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_best_model_pred, color = 'blue', label = 'HP Predicted data')
plt.title('HP Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
# checking the output metrics
from sklearn import metrics

y_hp_pred=y_best_model_pred

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_hp_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_hp_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hp_pred)))

y_mean = np.mean(y_hp_pred)
y_std = np.std(y_hp_pred)
print('Output Standard Deviation:', y_std)
print('Output Mean:', y_mean)
# Out:
# Mean Absolute Error: 0.663734823631872
# Mean Squared Error: 1.0242083512007414
# Root Mean Squared Error: 1.01203179357209
# Output Standard Deviation: 0.8064375
# Output Mean: 0.8861913

# %%
tuner_rs.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='loss', direction='min')
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: tanh
# dropout: 0.04
# dense_optimizer: SGD
# Score: 59.29666519165039
# Trial summary
# Hyperparameters:
# units: 24
# dense_activation: relu
# dropout: 0.09
# dense_optimizer: rmsprop
# Score: 61.06418418884277
# Trial summary
# Hyperparameters:
# units: 20
# dense_activation: sigmoid
# dropout: 0.09
# dense_optimizer: rmsprop
# Score: 62.68609809875488
# Trial summary
# Hyperparameters:
# units: 12
# dense_activation: sigmoid
# dropout: 0.09
# dense_optimizer: rmsprop
# Score: 62.746578216552734
