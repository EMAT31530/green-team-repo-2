# %% [markdown]
# Dont forget to normalise the data (he guesses boosted trees will be the best)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
nutrition = pd.read_pickle("./nutrition_data_clean.pkl")
nutrition
# Out:
#                                                    name   Food Group Branded?  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods      NaN
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods        X
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods        X
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods        X
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods        X
# ...                                                 ...          ...      ...
# 1218                                    Plantain Fried    Vegetables      NaN
# 1219                                Romaine Lettuce Raw   Vegetables      NaN
# 1220                                       Palak Paneer   Vegetables      NaN
# 1221                                  Carrots Raw Salad   Vegetables      NaN
# 1222                                   Corn on the cob    Vegetables      NaN
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  \
# 0          1.70           260.0                      0.653846
# 1          1.50           567.0                      0.264550
# 2          1.50           567.0                      0.264550
# 3          1.50           567.0                      0.264550
# 4          1.50           567.0                      0.264550
# ...         ...             ...                           ...
# 1218       0.90            85.0                      1.058824
# 1219       1.00           400.0                      0.250000
# 1220       3.75           500.0                      0.750000
# 1221       0.41          1000.0                      0.041000
# 1222       1.50           875.0                      0.171429
#
#            Carbon Group  Land use (m2/100g)  GHG(kgco2eq/100g)  \
# 0       Bread products               0.3482             0.1441
# 1       Bread products               0.3482             0.1441
# 2       Bread products               0.3482             0.1441
# 3       Bread products               0.3482             0.1441
# 4       Bread products               0.3482             0.1441
# ...                 ...                 ...                ...
# 1218  Other vegetables               0.0310             0.0455
# 1219  Other vegetables               0.0310             0.0455
# 1220            Cheese               8.0642             2.1240
# 1221  Other vegetables               0.0310             0.0455
# 1222  Other vegetables               0.0310             0.0455
#
#       Water use (L/100g)  Acidifying emissions(kgSO2eq/100g)  \
# 0                   56.7                            0.001209
# 1                   56.7                            0.001209
# 2                   56.7                            0.001209
# 3                   56.7                            0.001209
# 4                   56.7                            0.001209
# ...                  ...                                 ...
# 1218                 8.3                            0.000531
# 1219                 8.3                            0.000531
# 1220               473.5                            0.014894
# 1221                 8.3                            0.000531
# 1222                 8.3                            0.000531
#
#       Eutr emissions  (kg PO43-eq per 100g)  Calories  Fat (g)  Protein (g)  \
# 0                                  0.000706       330    11.27         4.34
# 1                                  0.000706       273     9.22         6.58
# 2                                  0.000706       309     9.49         7.42
# 3                                  0.000706       289     9.40         6.92
# 4                                  0.000706       298     9.91         6.71
# ...                                     ...       ...      ...          ...
# 1218                               0.000186       241    10.16         1.66
# 1219                               0.000186        19     0.27         1.39
# 1220                               0.008875        96     6.84         5.23
# 1221                               0.000186       208    15.70         1.22
# 1222                               0.000186        67     1.22         2.28
#
#       Carbohydrate (g)  Sugars (g)  Fiber (g)  Cholesterol (mg)  \
# 0                53.42       21.34        1.4               0.0
# 1                41.05        4.30        2.2              15.0
# 2                48.39        4.41        2.6              13.0
# 3                44.16        4.50        2.4              16.0
# 4                45.41        5.04        2.4              16.0
# ...                ...         ...        ...               ...
# 1218             40.60       19.10        2.9               0.0
# 1219              3.78        0.71        3.1               0.0
# 1220              4.32        1.89        1.2               7.0
# 1221             17.17       11.23        2.3               9.0
# 1222             14.30        4.43        2.0               0.0
#
#       Saturated Fats (g)
# 0                  3.250
# 1                  1.898
# 2                  2.275
# 3                  2.057
# 4                  1.580
# ...                  ...
# 1218               1.507
# 1219               0.053
# 1220               1.486
# 1221               2.452
# 1222               0.244
#
# [1223 rows x 20 columns]

# %% [markdown]
# Initially i want to ignore any collumns on carbon and just try to get a price predictor.

# %%
#cutting collumns 6 to 11
nutrition.drop(nutrition.columns[6:12], axis=1, inplace=True)
nutrition
# Out:
#                                                    name   Food Group Branded?  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods      NaN
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods        X
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods        X
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods        X
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods        X
# ...                                                 ...          ...      ...
# 1218                                    Plantain Fried    Vegetables      NaN
# 1219                                Romaine Lettuce Raw   Vegetables      NaN
# 1220                                       Palak Paneer   Vegetables      NaN
# 1221                                  Carrots Raw Salad   Vegetables      NaN
# 1222                                   Corn on the cob    Vegetables      NaN
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  Calories  \
# 0          1.70           260.0                      0.653846       330
# 1          1.50           567.0                      0.264550       273
# 2          1.50           567.0                      0.264550       309
# 3          1.50           567.0                      0.264550       289
# 4          1.50           567.0                      0.264550       298
# ...         ...             ...                           ...       ...
# 1218       0.90            85.0                      1.058824       241
# 1219       1.00           400.0                      0.250000        19
# 1220       3.75           500.0                      0.750000        96
# 1221       0.41          1000.0                      0.041000       208
# 1222       1.50           875.0                      0.171429        67
#
#       Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 0       11.27         4.34             53.42       21.34        1.4
# 1        9.22         6.58             41.05        4.30        2.2
# 2        9.49         7.42             48.39        4.41        2.6
# 3        9.40         6.92             44.16        4.50        2.4
# 4        9.91         6.71             45.41        5.04        2.4
# ...       ...          ...               ...         ...        ...
# 1218    10.16         1.66             40.60       19.10        2.9
# 1219     0.27         1.39              3.78        0.71        3.1
# 1220     6.84         5.23              4.32        1.89        1.2
# 1221    15.70         1.22             17.17       11.23        2.3
# 1222     1.22         2.28             14.30        4.43        2.0
#
#       Cholesterol (mg)  Saturated Fats (g)
# 0                  0.0               3.250
# 1                 15.0               1.898
# 2                 13.0               2.275
# 3                 16.0               2.057
# 4                 16.0               1.580
# ...                ...                 ...
# 1218               0.0               1.507
# 1219               0.0               0.053
# 1220               7.0               1.486
# 1221               9.0               2.452
# 1222               0.0               0.244
#
# [1223 rows x 14 columns]

# %%
#Cutting branded collumn(probably better to keep this and turn into 1s and 0s maybe)
nutrition.drop(nutrition.columns[2], axis=1, inplace=True)

# %%
nutrition.dropna(inplace=True) #getting rid of na values.

# %%
# Importing the dataset
X = nutrition.iloc[:, 5:].values
y = nutrition.iloc[:, 4].values
X, y
# Out:
# (array([[3.300e+02, 1.127e+01, 4.340e+00, ..., 1.400e+00, 0.000e+00,
#          3.250e+00],
#         [2.730e+02, 9.220e+00, 6.580e+00, ..., 2.200e+00, 1.500e+01,
#          1.898e+00],
#         [3.090e+02, 9.490e+00, 7.420e+00, ..., 2.600e+00, 1.300e+01,
#          2.275e+00],
#         ...,
#         [9.600e+01, 6.840e+00, 5.230e+00, ..., 1.200e+00, 7.000e+00,
#          1.486e+00],
#         [2.080e+02, 1.570e+01, 1.220e+00, ..., 2.300e+00, 9.000e+00,
#          2.452e+00],
#         [6.700e+01, 1.220e+00, 2.280e+00, ..., 2.000e+00, 0.000e+00,
#          2.440e-01]]),
#  array([0.65384615, 0.26455026, 0.26455026, ..., 0.75      , 0.041     ,
#         0.17142857]))

# %%
# i want to use info from collums 5 to 12 to predict price per weight ie collumn 4
print('num classes:', len(np.unique(y)))

num_classes = len(np.unique(y)) #checking how many classes we have
num_features = X.shape[1]
print(X.shape) #shape of our array
# Out:
# num classes: 543
# (1189, 8)

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Initialising the ANN
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(32, activation = 'relu', input_dim = 8))

# Adding the second hidden layer
model.add(Dense(units = 32, activation = 'relu'))

# Adding the third hidden layer
model.add(Dense(units = 32, activation = 'relu'))

# Adding the output layer

model.add(Dense(units = 1))

#model.add(Dense(1))
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the ANN to the Training set
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 0s 735us/step - loss: 125.2888
# Epoch 2/100
# 96/96 [==============================] - 0s 800us/step - loss: 3.1725
# Epoch 3/100
# 96/96 [==============================] - 0s 799us/step - loss: 10.0606
# Epoch 4/100
# 96/96 [==============================] - 0s 766us/step - loss: 68.1172
# Epoch 5/100
# 96/96 [==============================] - 0s 810us/step - loss: 16.0024
# Epoch 6/100
# 96/96 [==============================] - 0s 784us/step - loss: 26.1569
# Epoch 7/100
# 96/96 [==============================] - 0s 777us/step - loss: 116.6347
# Epoch 8/100
# 96/96 [==============================] - 0s 804us/step - loss: 91.5010
# Epoch 9/100
# 96/96 [==============================] - 0s 746us/step - loss: 13.3226
# Epoch 10/100
# 96/96 [==============================] - 0s 791us/step - loss: 7.4911
# Epoch 11/100
# 96/96 [==============================] - 0s 793us/step - loss: 53.4288
# Epoch 12/100
# 96/96 [==============================] - 0s 798us/step - loss: 11.6362
# Epoch 13/100
# 96/96 [==============================] - 0s 812us/step - loss: 11.7726
# Epoch 14/100
# 96/96 [==============================] - 0s 813us/step - loss: 139.3024
# Epoch 15/100
# 96/96 [==============================] - 0s 794us/step - loss: 43.2891
# Epoch 16/100
# 96/96 [==============================] - 0s 843us/step - loss: 12.9608
# Epoch 17/100
# 96/96 [==============================] - 0s 821us/step - loss: 61.8448
# Epoch 18/100
# 96/96 [==============================] - 0s 779us/step - loss: 7.4500
# Epoch 19/100
# 96/96 [==============================] - 0s 898us/step - loss: 49.9474
# Epoch 20/100
# 96/96 [==============================] - 0s 824us/step - loss: 16.1971
# Epoch 21/100
# 96/96 [==============================] - 0s 790us/step - loss: 29.7224
# Epoch 22/100
# 96/96 [==============================] - 0s 836us/step - loss: 45.7280
# Epoch 23/100
# 96/96 [==============================] - 0s 866us/step - loss: 16.6131
# Epoch 24/100
# 96/96 [==============================] - 0s 811us/step - loss: 86.8584
# Epoch 25/100
# 96/96 [==============================] - 0s 796us/step - loss: 54.5751
# Epoch 26/100
# 96/96 [==============================] - 0s 802us/step - loss: 24.5721
# Epoch 27/100
# 96/96 [==============================] - 0s 829us/step - loss: 16.1833
# Epoch 28/100
# 96/96 [==============================] - 0s 834us/step - loss: 12.3174
# Epoch 29/100
# 96/96 [==============================] - 0s 838us/step - loss: 20.6362
# Epoch 30/100
# 96/96 [==============================] - 0s 845us/step - loss: 37.5524
# Epoch 31/100
# 96/96 [==============================] - 0s 851us/step - loss: 32.7639
# Epoch 32/100
# 96/96 [==============================] - 0s 809us/step - loss: 65.4714
# Epoch 33/100
# 96/96 [==============================] - 0s 803us/step - loss: 20.0303
# Epoch 34/100
# 96/96 [==============================] - 0s 795us/step - loss: 15.0599
# Epoch 35/100
# 96/96 [==============================] - 0s 852us/step - loss: 23.6412
# Epoch 36/100
# 96/96 [==============================] - 0s 807us/step - loss: 26.9310
# Epoch 37/100
# 96/96 [==============================] - 0s 790us/step - loss: 98.5402
# Epoch 38/100
# 96/96 [==============================] - 0s 802us/step - loss: 46.2202
# Epoch 39/100
# 96/96 [==============================] - 0s 828us/step - loss: 47.4628
# Epoch 40/100
# 96/96 [==============================] - 0s 796us/step - loss: 27.3058
# Epoch 41/100
# 96/96 [==============================] - 0s 813us/step - loss: 81.4548
# Epoch 42/100
# 96/96 [==============================] - 0s 846us/step - loss: 66.2456
# Epoch 43/100
# 96/96 [==============================] - 0s 764us/step - loss: 5.8723
# Epoch 44/100
# 96/96 [==============================] - 0s 796us/step - loss: 40.3571
# Epoch 45/100
# 96/96 [==============================] - 0s 782us/step - loss: 31.1469
# Epoch 46/100
# 96/96 [==============================] - 0s 786us/step - loss: 139.2430
# Epoch 47/100
# 96/96 [==============================] - 0s 762us/step - loss: 10.1514
# Epoch 48/100
# 96/96 [==============================] - 0s 806us/step - loss: 102.7882
# Epoch 49/100
# 96/96 [==============================] - 0s 799us/step - loss: 9.6381
# Epoch 50/100
# 96/96 [==============================] - 0s 796us/step - loss: 9.9988
# Epoch 51/100
# 96/96 [==============================] - 0s 817us/step - loss: 95.0502
# Epoch 52/100
# 96/96 [==============================] - 0s 794us/step - loss: 16.9328
# Epoch 53/100
# 96/96 [==============================] - 0s 870us/step - loss: 17.9360
# Epoch 54/100
# 96/96 [==============================] - 0s 843us/step - loss: 34.5920
# Epoch 55/100
# 96/96 [==============================] - 0s 841us/step - loss: 33.5502
# Epoch 56/100
# 96/96 [==============================] - 0s 795us/step - loss: 94.7919
# Epoch 57/100
# 96/96 [==============================] - 0s 795us/step - loss: 36.3167
# Epoch 58/100
# 96/96 [==============================] - 0s 779us/step - loss: 21.3088
# Epoch 59/100
# 96/96 [==============================] - 0s 761us/step - loss: 19.4327
# Epoch 60/100
# 96/96 [==============================] - 0s 755us/step - loss: 41.0127
# Epoch 61/100
# 96/96 [==============================] - 0s 790us/step - loss: 49.9343
# Epoch 62/100
# 96/96 [==============================] - 0s 902us/step - loss: 17.8744
# Epoch 63/100
# 96/96 [==============================] - 0s 901us/step - loss: 37.9337
# Epoch 64/100
# 96/96 [==============================] - 0s 898us/step - loss: 11.3406
# Epoch 65/100
# 96/96 [==============================] - 0s 887us/step - loss: 19.9960
# Epoch 66/100
# 96/96 [==============================] - 0s 910us/step - loss: 13.0667
# Epoch 67/100
# 96/96 [==============================] - 0s 913us/step - loss: 42.1295
# Epoch 68/100
# 96/96 [==============================] - 0s 882us/step - loss: 26.5141
# Epoch 69/100
# 96/96 [==============================] - 0s 901us/step - loss: 46.0202
# Epoch 70/100
# 96/96 [==============================] - 0s 1ms/step - loss: 28.6206
# Epoch 71/100
# 96/96 [==============================] - 0s 805us/step - loss: 26.6798
# Epoch 72/100
# 96/96 [==============================] - 0s 817us/step - loss: 18.8840
# Epoch 73/100
# 96/96 [==============================] - 0s 851us/step - loss: 14.7152
# Epoch 74/100
# 96/96 [==============================] - 0s 850us/step - loss: 62.9029
# Epoch 75/100
# 96/96 [==============================] - 0s 831us/step - loss: 3.0871
# Epoch 76/100
# 96/96 [==============================] - 0s 844us/step - loss: 164.7528
# Epoch 77/100
# 96/96 [==============================] - 0s 891us/step - loss: 71.6473
# Epoch 78/100
# 96/96 [==============================] - 0s 844us/step - loss: 43.4700
# Epoch 79/100
# 96/96 [==============================] - 0s 922us/step - loss: 24.1635
# Epoch 80/100
# 96/96 [==============================] - 0s 859us/step - loss: 45.1233
# Epoch 81/100
# 96/96 [==============================] - 0s 918us/step - loss: 64.6157
# Epoch 82/100
# 96/96 [==============================] - 0s 890us/step - loss: 7.5247
# Epoch 83/100
# 96/96 [==============================] - 0s 901us/step - loss: 9.3405
# Epoch 84/100
# 96/96 [==============================] - 0s 860us/step - loss: 43.7821
# Epoch 85/100
# 96/96 [==============================] - 0s 927us/step - loss: 45.4956
# Epoch 86/100
# 96/96 [==============================] - 0s 961us/step - loss: 18.7539
# Epoch 87/100
# 96/96 [==============================] - 0s 909us/step - loss: 27.6634
# Epoch 88/100
# 96/96 [==============================] - 0s 923us/step - loss: 17.2050
# Epoch 89/100
# 96/96 [==============================] - 0s 900us/step - loss: 9.7248
# Epoch 90/100
# 96/96 [==============================] - 0s 982us/step - loss: 34.0537
# Epoch 91/100
# 96/96 [==============================] - 0s 905us/step - loss: 11.0456
# Epoch 92/100
# 96/96 [==============================] - 0s 988us/step - loss: 11.0302
# Epoch 93/100
# 96/96 [==============================] - 0s 882us/step - loss: 19.3018
# Epoch 94/100
# 96/96 [==============================] - 0s 942us/step - loss: 39.3127
# Epoch 95/100
# 96/96 [==============================] - 0s 885us/step - loss: 60.8315
# Epoch 96/100
# 96/96 [==============================] - 0s 930us/step - loss: 13.8661
# Epoch 97/100
# 96/96 [==============================] - 0s 964us/step - loss: 17.6869
# Epoch 98/100
# 96/96 [==============================] - 0s 945us/step - loss: 38.9863
# Epoch 99/100
# 96/96 [==============================] - 0s 868us/step - loss: 8.7268
# Epoch 100/100
# 96/96 [==============================] - 0s 877us/step - loss: 27.7916

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

#plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression
