# %% [markdown]
# Dont forget to normalise the data (he guesses boosted trees will be the best)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
nutrition = pd.read_pickle("./nutrition_data_clean.pkl")
nutrition
# Out:
#                                                    name   Food Group Branded?  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods      NaN
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods        X
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods        X
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods        X
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods        X
# ...                                                 ...          ...      ...
# 1218                                    Plantain Fried    Vegetables      NaN
# 1219                                Romaine Lettuce Raw   Vegetables      NaN
# 1220                                       Palak Paneer   Vegetables      NaN
# 1221                                  Carrots Raw Salad   Vegetables      NaN
# 1222                                   Corn on the cob    Vegetables      NaN
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  \
# 0          1.70           260.0                      0.653846
# 1          1.50           567.0                      0.264550
# 2          1.50           567.0                      0.264550
# 3          1.50           567.0                      0.264550
# 4          1.50           567.0                      0.264550
# ...         ...             ...                           ...
# 1218       0.90            85.0                      1.058824
# 1219       1.00           400.0                      0.250000
# 1220       3.75           500.0                      0.750000
# 1221       0.41          1000.0                      0.041000
# 1222       1.50           875.0                      0.171429
#
#            Carbon Group  Land use (m2/100g)  GHG(kgco2eq/100g)  \
# 0       Bread products               0.3482             0.1441
# 1       Bread products               0.3482             0.1441
# 2       Bread products               0.3482             0.1441
# 3       Bread products               0.3482             0.1441
# 4       Bread products               0.3482             0.1441
# ...                 ...                 ...                ...
# 1218  Other vegetables               0.0310             0.0455
# 1219  Other vegetables               0.0310             0.0455
# 1220            Cheese               8.0642             2.1240
# 1221  Other vegetables               0.0310             0.0455
# 1222  Other vegetables               0.0310             0.0455
#
#       Water use (L/100g)  Acidifying emissions(kgSO2eq/100g)  \
# 0                   56.7                            0.001209
# 1                   56.7                            0.001209
# 2                   56.7                            0.001209
# 3                   56.7                            0.001209
# 4                   56.7                            0.001209
# ...                  ...                                 ...
# 1218                 8.3                            0.000531
# 1219                 8.3                            0.000531
# 1220               473.5                            0.014894
# 1221                 8.3                            0.000531
# 1222                 8.3                            0.000531
#
#       Eutr emissions  (kg PO43-eq per 100g)  Calories  Fat (g)  Protein (g)  \
# 0                                  0.000706       330    11.27         4.34
# 1                                  0.000706       273     9.22         6.58
# 2                                  0.000706       309     9.49         7.42
# 3                                  0.000706       289     9.40         6.92
# 4                                  0.000706       298     9.91         6.71
# ...                                     ...       ...      ...          ...
# 1218                               0.000186       241    10.16         1.66
# 1219                               0.000186        19     0.27         1.39
# 1220                               0.008875        96     6.84         5.23
# 1221                               0.000186       208    15.70         1.22
# 1222                               0.000186        67     1.22         2.28
#
#       Carbohydrate (g)  Sugars (g)  Fiber (g)  Cholesterol (mg)  \
# 0                53.42       21.34        1.4               0.0
# 1                41.05        4.30        2.2              15.0
# 2                48.39        4.41        2.6              13.0
# 3                44.16        4.50        2.4              16.0
# 4                45.41        5.04        2.4              16.0
# ...                ...         ...        ...               ...
# 1218             40.60       19.10        2.9               0.0
# 1219              3.78        0.71        3.1               0.0
# 1220              4.32        1.89        1.2               7.0
# 1221             17.17       11.23        2.3               9.0
# 1222             14.30        4.43        2.0               0.0
#
#       Saturated Fats (g)
# 0                  3.250
# 1                  1.898
# 2                  2.275
# 3                  2.057
# 4                  1.580
# ...                  ...
# 1218               1.507
# 1219               0.053
# 1220               1.486
# 1221               2.452
# 1222               0.244
#
# [1223 rows x 20 columns]

# %% [markdown]
# Initially i want to ignore any collumns on carbon and just try to get a price predictor.

# %%
#cutting collumns 6 to 11
nutrition.drop(nutrition.columns[6:12], axis=1, inplace=True)
nutrition
# Out:
#                                                    name   Food Group Branded?  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods      NaN
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods        X
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods        X
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods        X
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods        X
# ...                                                 ...          ...      ...
# 1218                                    Plantain Fried    Vegetables      NaN
# 1219                                Romaine Lettuce Raw   Vegetables      NaN
# 1220                                       Palak Paneer   Vegetables      NaN
# 1221                                  Carrots Raw Salad   Vegetables      NaN
# 1222                                   Corn on the cob    Vegetables      NaN
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  Calories  \
# 0          1.70           260.0                      0.653846       330
# 1          1.50           567.0                      0.264550       273
# 2          1.50           567.0                      0.264550       309
# 3          1.50           567.0                      0.264550       289
# 4          1.50           567.0                      0.264550       298
# ...         ...             ...                           ...       ...
# 1218       0.90            85.0                      1.058824       241
# 1219       1.00           400.0                      0.250000        19
# 1220       3.75           500.0                      0.750000        96
# 1221       0.41          1000.0                      0.041000       208
# 1222       1.50           875.0                      0.171429        67
#
#       Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 0       11.27         4.34             53.42       21.34        1.4
# 1        9.22         6.58             41.05        4.30        2.2
# 2        9.49         7.42             48.39        4.41        2.6
# 3        9.40         6.92             44.16        4.50        2.4
# 4        9.91         6.71             45.41        5.04        2.4
# ...       ...          ...               ...         ...        ...
# 1218    10.16         1.66             40.60       19.10        2.9
# 1219     0.27         1.39              3.78        0.71        3.1
# 1220     6.84         5.23              4.32        1.89        1.2
# 1221    15.70         1.22             17.17       11.23        2.3
# 1222     1.22         2.28             14.30        4.43        2.0
#
#       Cholesterol (mg)  Saturated Fats (g)
# 0                  0.0               3.250
# 1                 15.0               1.898
# 2                 13.0               2.275
# 3                 16.0               2.057
# 4                 16.0               1.580
# ...                ...                 ...
# 1218               0.0               1.507
# 1219               0.0               0.053
# 1220               7.0               1.486
# 1221               9.0               2.452
# 1222               0.0               0.244
#
# [1223 rows x 14 columns]

# %%
#Cutting branded collumn(probably better to keep this and turn into 1s and 0s maybe)
nutrition.drop(nutrition.columns[2], axis=1, inplace=True)

# %%
nutrition.dropna() #getting rid of na values.
# Out:
#                                                    name   Food Group  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods
# ...                                                 ...          ...
# 1218                                    Plantain Fried    Vegetables
# 1219                                Romaine Lettuce Raw   Vegetables
# 1220                                       Palak Paneer   Vegetables
# 1221                                  Carrots Raw Salad   Vegetables
# 1222                                   Corn on the cob    Vegetables
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  Calories  \
# 0          1.70           260.0                      0.653846       330
# 1          1.50           567.0                      0.264550       273
# 2          1.50           567.0                      0.264550       309
# 3          1.50           567.0                      0.264550       289
# 4          1.50           567.0                      0.264550       298
# ...         ...             ...                           ...       ...
# 1218       0.90            85.0                      1.058824       241
# 1219       1.00           400.0                      0.250000        19
# 1220       3.75           500.0                      0.750000        96
# 1221       0.41          1000.0                      0.041000       208
# 1222       1.50           875.0                      0.171429        67
#
#       Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 0       11.27         4.34             53.42       21.34        1.4
# 1        9.22         6.58             41.05        4.30        2.2
# 2        9.49         7.42             48.39        4.41        2.6
# 3        9.40         6.92             44.16        4.50        2.4
# 4        9.91         6.71             45.41        5.04        2.4
# ...       ...          ...               ...         ...        ...
# 1218    10.16         1.66             40.60       19.10        2.9
# 1219     0.27         1.39              3.78        0.71        3.1
# 1220     6.84         5.23              4.32        1.89        1.2
# 1221    15.70         1.22             17.17       11.23        2.3
# 1222     1.22         2.28             14.30        4.43        2.0
#
#       Cholesterol (mg)  Saturated Fats (g)
# 0                  0.0               3.250
# 1                 15.0               1.898
# 2                 13.0               2.275
# 3                 16.0               2.057
# 4                 16.0               1.580
# ...                ...                 ...
# 1218               0.0               1.507
# 1219               0.0               0.053
# 1220               7.0               1.486
# 1221               9.0               2.452
# 1222               0.0               0.244
#
# [1189 rows x 13 columns]

# %%
# Importing the dataset

X = nutrition.iloc[:, 5:].values
y = nutrition.iloc[:, 4].values
X
y
# Out:
# array([[3.300e+02, 1.127e+01, 4.340e+00, ..., 1.400e+00, 0.000e+00,
#         3.250e+00],
#        [2.730e+02, 9.220e+00, 6.580e+00, ..., 2.200e+00, 1.500e+01,
#         1.898e+00],
#        [3.090e+02, 9.490e+00, 7.420e+00, ..., 2.600e+00, 1.300e+01,
#         2.275e+00],
#        ...,
#        [9.600e+01, 6.840e+00, 5.230e+00, ..., 1.200e+00, 7.000e+00,
#         1.486e+00],
#        [2.080e+02, 1.570e+01, 1.220e+00, ..., 2.300e+00, 9.000e+00,
#         2.452e+00],
#        [6.700e+01, 1.220e+00, 2.280e+00, ..., 2.000e+00, 0.000e+00,
#         2.440e-01]])

# %%
# i want to use info from collums 5 to 12 to predict price per weight ie collumn 4
print('num classes:', len(np.unique(y)))

num_classes = len(np.unique(y)) #checking how many classes we have
num_features = X.shape[1]
print(X.shape) #shape of our array
# Out:
# num classes: 547
# (1223, 8)

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Initialising the ANN
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(32, activation = 'relu', input_dim = 8))

# Adding the second hidden layer
model.add(Dense(units = 32, activation = 'relu'))

# Adding the third hidden layer
model.add(Dense(units = 32, activation = 'relu'))

# Adding the output layer

model.add(Dense(units = 1))

#model.add(Dense(1))
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the ANN to the Training set
model.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 98/98 [==============================] - 0s 709us/step - loss: nan
# Epoch 2/100
# 98/98 [==============================] - 0s 621us/step - loss: nan
# Epoch 3/100
# 98/98 [==============================] - 0s 624us/step - loss: nan
# Epoch 4/100
# 98/98 [==============================] - 0s 639us/step - loss: nan
# Epoch 5/100
# 98/98 [==============================] - 0s 797us/step - loss: nan
# Epoch 6/100
# 98/98 [==============================] - 0s 755us/step - loss: nan
# Epoch 7/100
# 98/98 [==============================] - 0s 759us/step - loss: nan
# Epoch 8/100
# 98/98 [==============================] - 0s 681us/step - loss: nan
# Epoch 9/100
# 98/98 [==============================] - 0s 692us/step - loss: nan
# Epoch 10/100
# 98/98 [==============================] - 0s 702us/step - loss: nan
# Epoch 11/100
# 98/98 [==============================] - 0s 668us/step - loss: nan
# Epoch 12/100
# 98/98 [==============================] - 0s 700us/step - loss: nan
# Epoch 13/100
# 98/98 [==============================] - 0s 685us/step - loss: nan
# Epoch 14/100
# 98/98 [==============================] - 0s 654us/step - loss: nan
# Epoch 15/100
# 98/98 [==============================] - 0s 665us/step - loss: nan
# Epoch 16/100
# 98/98 [==============================] - 0s 669us/step - loss: nan
# Epoch 17/100
# 98/98 [==============================] - 0s 693us/step - loss: nan
# Epoch 18/100
# 98/98 [==============================] - 0s 662us/step - loss: nan
# Epoch 19/100
# 98/98 [==============================] - 0s 664us/step - loss: nan
# Epoch 20/100
# 98/98 [==============================] - 0s 669us/step - loss: nan
# Epoch 21/100
# 98/98 [==============================] - 0s 667us/step - loss: nan
# Epoch 22/100
# 98/98 [==============================] - 0s 699us/step - loss: nan
# Epoch 23/100
# 98/98 [==============================] - 0s 684us/step - loss: nan
# Epoch 24/100
# 98/98 [==============================] - 0s 651us/step - loss: nan
# Epoch 25/100
# 98/98 [==============================] - 0s 618us/step - loss: nan
# Epoch 26/100
# 98/98 [==============================] - 0s 618us/step - loss: nan
# Epoch 27/100
# 98/98 [==============================] - 0s 634us/step - loss: nan
# Epoch 28/100
# 98/98 [==============================] - 0s 637us/step - loss: nan
# Epoch 29/100
# 98/98 [==============================] - 0s 629us/step - loss: nan
# Epoch 30/100
# 98/98 [==============================] - 0s 622us/step - loss: nan
# Epoch 31/100
# 98/98 [==============================] - 0s 636us/step - loss: nan
# Epoch 32/100
# 98/98 [==============================] - 0s 636us/step - loss: nan
# Epoch 33/100
# 98/98 [==============================] - 0s 637us/step - loss: nan
# Epoch 34/100
# 98/98 [==============================] - 0s 629us/step - loss: nan
# Epoch 35/100
# 98/98 [==============================] - 0s 618us/step - loss: nan
# Epoch 36/100
# 98/98 [==============================] - 0s 686us/step - loss: nan
# Epoch 37/100
# 98/98 [==============================] - 0s 641us/step - loss: nan
# Epoch 38/100
# 98/98 [==============================] - 0s 628us/step - loss: nan
# Epoch 39/100
# 98/98 [==============================] - 0s 613us/step - loss: nan
# Epoch 40/100
# 98/98 [==============================] - 0s 614us/step - loss: nan
# Epoch 41/100
# 98/98 [==============================] - 0s 633us/step - loss: nan
# Epoch 42/100
# 98/98 [==============================] - 0s 621us/step - loss: nan
# Epoch 43/100
# 98/98 [==============================] - 0s 615us/step - loss: nan
# Epoch 44/100
# 98/98 [==============================] - 0s 604us/step - loss: nan
# Epoch 45/100
# 98/98 [==============================] - 0s 617us/step - loss: nan
# Epoch 46/100
# 98/98 [==============================] - 0s 605us/step - loss: nan
# Epoch 47/100
# 98/98 [==============================] - 0s 623us/step - loss: nan
# Epoch 48/100
# 98/98 [==============================] - 0s 628us/step - loss: nan
# Epoch 49/100
# 98/98 [==============================] - 0s 617us/step - loss: nan
# Epoch 50/100
# 98/98 [==============================] - 0s 617us/step - loss: nan
# Epoch 51/100
# 98/98 [==============================] - 0s 620us/step - loss: nan
# Epoch 52/100
# 98/98 [==============================] - 0s 623us/step - loss: nan
# Epoch 53/100
# 98/98 [==============================] - 0s 647us/step - loss: nan
# Epoch 54/100
# 98/98 [==============================] - 0s 597us/step - loss: nan
# Epoch 55/100
# 98/98 [==============================] - 0s 588us/step - loss: nan
# Epoch 56/100
# 98/98 [==============================] - 0s 578us/step - loss: nan
# Epoch 57/100
# 98/98 [==============================] - 0s 613us/step - loss: nan
# Epoch 58/100
# 98/98 [==============================] - 0s 667us/step - loss: nan
# Epoch 59/100
# 98/98 [==============================] - 0s 672us/step - loss: nan
# Epoch 60/100
# 98/98 [==============================] - 0s 665us/step - loss: nan
# Epoch 61/100
# 98/98 [==============================] - 0s 652us/step - loss: nan
# Epoch 62/100
# 98/98 [==============================] - 0s 721us/step - loss: nan
# Epoch 63/100
# 98/98 [==============================] - 0s 782us/step - loss: nan
# Epoch 64/100
# 98/98 [==============================] - 0s 671us/step - loss: nan
# Epoch 65/100
# 98/98 [==============================] - 0s 726us/step - loss: nan
# Epoch 66/100
# 98/98 [==============================] - 0s 717us/step - loss: nan
# Epoch 67/100
# 98/98 [==============================] - 0s 586us/step - loss: nan
# Epoch 68/100
# 98/98 [==============================] - 0s 592us/step - loss: nan
# Epoch 69/100
# 98/98 [==============================] - 0s 581us/step - loss: nan
# Epoch 70/100
# 98/98 [==============================] - 0s 599us/step - loss: nan
# Epoch 71/100
# 98/98 [==============================] - 0s 577us/step - loss: nan
# Epoch 72/100
# 98/98 [==============================] - 0s 593us/step - loss: nan
# Epoch 73/100
# 98/98 [==============================] - 0s 577us/step - loss: nan
# Epoch 74/100
# 98/98 [==============================] - 0s 599us/step - loss: nan
# Epoch 75/100
# 98/98 [==============================] - 0s 585us/step - loss: nan
# Epoch 76/100
# 98/98 [==============================] - 0s 587us/step - loss: nan
# Epoch 77/100
# 98/98 [==============================] - 0s 581us/step - loss: nan
# Epoch 78/100
# 98/98 [==============================] - 0s 592us/step - loss: nan
# Epoch 79/100
# 98/98 [==============================] - 0s 570us/step - loss: nan
# Epoch 80/100
# 98/98 [==============================] - 0s 588us/step - loss: nan
# Epoch 81/100
# 98/98 [==============================] - 0s 578us/step - loss: nan
# Epoch 82/100
# 98/98 [==============================] - 0s 587us/step - loss: nan
# Epoch 83/100
# 98/98 [==============================] - 0s 575us/step - loss: nan
# Epoch 84/100
# 98/98 [==============================] - 0s 592us/step - loss: nan
# Epoch 85/100
# 98/98 [==============================] - 0s 578us/step - loss: nan
# Epoch 86/100
# 98/98 [==============================] - 0s 598us/step - loss: nan
# Epoch 87/100
# 98/98 [==============================] - 0s 595us/step - loss: nan
# Epoch 88/100
# 98/98 [==============================] - 0s 577us/step - loss: nan
# Epoch 89/100
# 98/98 [==============================] - 0s 595us/step - loss: nan
# Epoch 90/100
# 98/98 [==============================] - 0s 578us/step - loss: nan
# Epoch 91/100
# 98/98 [==============================] - 0s 595us/step - loss: nan
# Epoch 92/100
# 98/98 [==============================] - 0s 573us/step - loss: nan
# Epoch 93/100
# 98/98 [==============================] - 0s 597us/step - loss: nan
# Epoch 94/100
# 98/98 [==============================] - 0s 579us/step - loss: nan
# Epoch 95/100
# 98/98 [==============================] - 0s 588us/step - loss: nan
# Epoch 96/100
# 98/98 [==============================] - 0s 592us/step - loss: nan
# Epoch 97/100
# 98/98 [==============================] - 0s 598us/step - loss: nan
# Epoch 98/100
# 98/98 [==============================] - 0s 581us/step - loss: nan
# Epoch 99/100
# 98/98 [==============================] - 0s 598us/step - loss: nan
# Epoch 100/100
# 98/98 [==============================] - 0s 577us/step - loss: nan

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)

#plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression
