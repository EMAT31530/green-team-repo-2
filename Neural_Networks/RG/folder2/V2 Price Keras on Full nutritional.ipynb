# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
import tensorflow
import keras

# %%
nutrition = pd.read_pickle("./Nutrition_Full_Features.pkl")
nutrition
# Out:
#                                                 name   Food Group  Price (£)  \
# 1            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods       1.50
# 2     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods       1.50
# 5                                    Dutch Apple Pie  Baked Foods       2.80
# 9                                  Bread White Wheat  Baked Foods       0.95
# 10                                      Bagels Wheat  Baked Foods       1.60
# ...                                              ...          ...        ...
# 1218                                 Plantain Fried    Vegetables       0.90
# 1219                             Romaine Lettuce Raw   Vegetables       1.00
# 1220                                    Palak Paneer   Vegetables       3.75
# 1221                               Carrots Raw Salad   Vegetables       0.41
# 1222                                Corn on the cob    Vegetables       1.50
#
#       Weight (GRAMS)  Price per Weight (£/100Gram)       Carbon Group  \
# 1              567.0                      0.264550    Bread products
# 2              567.0                      0.264550    Bread products
# 5              500.0                      0.560000    Bread products
# 9              800.0                      0.118750    Bread products
# 10             450.0                      0.355556    Bread products
# ...              ...                           ...                ...
# 1218            85.0                      1.058824  Other vegetables
# 1219           400.0                      0.250000  Other vegetables
# 1220           500.0                      0.750000            Cheese
# 1221          1000.0                      0.041000  Other vegetables
# 1222           875.0                      0.171429  Other vegetables
#
#       Land use (m2/100g)  GHG(kgco2eq/100g)  Water use (L/100g)  \
# 1                 0.3482             0.1441                56.7
# 2                 0.3482             0.1441                56.7
# 5                 0.3482             0.1441                56.7
# 9                 0.3482             0.1441                56.7
# 10                0.3482             0.1441                56.7
# ...                  ...                ...                 ...
# 1218              0.0310             0.0455                 8.3
# 1219              0.0310             0.0455                 8.3
# 1220              8.0642             2.1240               473.5
# 1221              0.0310             0.0455                 8.3
# 1222              0.0310             0.0455                 8.3
#
#       Acidifying emissions(kgSO2eq per 100g)  ...  Carotene, alpha (mcg)  \
# 1                                   0.001209  ...                    0.0
# 2                                   0.001209  ...                    0.0
# 5                                   0.001209  ...                    0.0
# 9                                   0.001209  ...                    0.0
# 10                                  0.001209  ...                    0.0
# ...                                      ...  ...                    ...
# 1218                                0.000531  ...                  418.0
# 1219                                0.000531  ...                    0.0
# 1220                                0.014894  ...                   12.0
# 1221                                0.000531  ...                 2157.0
# 1222                                0.000531  ...                    6.0
#
#       Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                0.0                       63.0
# 2                0.0                       66.0
# 5                1.0                       42.0
# 9                0.0                       25.0
# 10               0.0                       88.0
# ...              ...                        ...
# 1218             0.0                       29.0
# 1219             0.0                     4204.0
# 1220           313.0                     4097.0
# 1221             1.0                      162.0
# 1222             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 51 columns]

# %%
#Data for features
X = nutrition.iloc[:, 11:]
y = nutrition.iloc[:, 4]

# %%
X
# Out:
#       Calories  Fat (g)  Protein (g)  Carbohydrate (g)  Sugars (g)  Fiber (g)  \
# 1          273     9.22         6.58             41.05        4.30        2.2
# 2          309     9.49         7.42             48.39        4.41        2.6
# 5          290    11.50         2.17             44.54       22.02        1.6
# 9          238     2.15        10.66             43.91        5.00        9.2
# 10         250     1.53        10.20             48.89        6.12        4.1
# ...        ...      ...          ...               ...         ...        ...
# 1218       241    10.16         1.66             40.60       19.10        2.9
# 1219        19     0.27         1.39              3.78        0.71        3.1
# 1220        96     6.84         5.23              4.32        1.89        1.2
# 1221       208    15.70         1.22             17.17       11.23        2.3
# 1222        67     1.22         2.28             14.30        4.43        2.0
#
#       Saturated Fats (g)  Calcium (mg)  Iron, Fe (mg)  Potassium, K (mg)  ...  \
# 1                  1.898           279           6.04              126.0  ...
# 2                  2.275           299           6.59              138.0  ...
# 5                  2.313            14           0.91               76.0  ...
# 9                  0.630           684           4.89              127.0  ...
# 10                 0.000            20           2.76              165.0  ...
# ...                  ...           ...            ...                ...  ...
# 1218               1.507             4           0.78              572.0  ...
# 1219               0.053            62           0.90              327.0  ...
# 1220               1.486            70           1.15              269.0  ...
# 1221               2.452            30           0.49              309.0  ...
# 1222               0.244             3           0.27              132.0  ...
#
#       Carotene, alpha (mcg)  Lycopene (mcg)  Lutein + Zeaxanthin (mcg)  \
# 1                       0.0             0.0                       63.0
# 2                       0.0             0.0                       66.0
# 5                       0.0             1.0                       42.0
# 9                       0.0             0.0                       25.0
# 10                      0.0             0.0                       88.0
# ...                     ...             ...                        ...
# 1218                  418.0             0.0                       29.0
# 1219                    0.0             0.0                     4204.0
# 1220                   12.0           313.0                     4097.0
# 1221                 2157.0             1.0                      162.0
# 1222                    6.0             0.0                      693.0
#
#       Fatty acids, total monounsaturated (mg)  \
# 1                                      4530.0
# 2                                      5292.0
# 5                                      5797.0
# 9                                       393.0
# 10                                      290.0
# ...                                       ...
# 1218                                   4099.0
# 1219                                      7.0
# 1220                                   2402.0
# 1221                                   3498.0
# 1222                                    373.0
#
#       Fatty acids, total polyunsaturated (mg)  20:5 n-3 (EPA) (mg)  \
# 1                                      1445.0                 12.0
# 2                                      1502.0                 13.0
# 5                                      2117.0                  0.0
# 9                                       973.0                  3.0
# 10                                      936.0                  0.0
# ...                                       ...                  ...
# 1218                                   4079.0                  0.0
# 1219                                    126.0                  0.0
# 1220                                   2112.0                  0.0
# 1221                                   9319.0                  0.0
# 1222                                    518.0                  0.0
#
#       22:5 n-3 (DPA) (mg)  22:6 n-3 (DHA) (mg)  Caffeine (mg)  \
# 1                     0.0                  7.0            0.0
# 2                     0.0                  8.0            0.0
# 5                     0.0                  0.0            0.0
# 9                     0.0                  0.0            0.0
# 10                    0.0                  0.0            0.0
# ...                   ...                  ...            ...
# 1218                  0.0                  0.0            0.0
# 1219                  0.0                  0.0            0.0
# 1220                  0.0                  0.0            0.0
# 1221                  0.0                  1.0            0.0
# 1222                  0.0                  0.0            0.0
#
#       Theobromine (mg)
# 1                  0.0
# 2                  0.0
# 5                  0.0
# 9                  0.0
# 10                 0.0
# ...                ...
# 1218               0.0
# 1219               0.0
# 1220               0.0
# 1221               0.0
# 1222               0.0
#
# [1042 rows x 40 columns]

# %%
y
# Out:
# 1       0.264550
# 2       0.264550
# 5       0.560000
# 9       0.118750
# 10      0.355556
#           ...
# 1218    1.058824
# 1219    0.250000
# 1220    0.750000
# 1221    0.041000
# 1222    0.171429
# Name: Price per Weight (£/100Gram), Length: 1042, dtype: float64

# %%
# command/
#only normalising X not y. Is this right?
# norm_X = preprocessing.normalize(X, axis=0) #collum instead of row
# norm_X = pd.DataFrame(norm_X, columns = X.columns)
# X=norm_X
# X

# %%
y = np.ravel(y)
X = X.values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
from keras.layers import Dense, Activation
from keras.models import Sequential

# Feature Scaling/preprocessing - normalization
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Building model
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(16, activation = 'relu', input_dim = 40))

# Adding the second hidden layer
model.add(Dense(units = 8, activation = 'relu'))

#avoids overfitting
#https://keras.io/api/layers/regularization_layers/dropout/
model.add(keras.layers.Dropout(0.1))


# Adding the output layer

model.add(Dense(units = 1))


# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'mse', metrics=['mae'])#metrics tracks values but doesn't decide with it

# Fitting the ANN to the Training set
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 1s 12ms/step - loss: 1.1418 - mae: 0.6444 - val_loss: 205.5650 - val_mae: 1.5796
# Epoch 2/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.5682 - mae: 0.5547 - val_loss: 205.1881 - val_mae: 1.5400
# Epoch 3/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.8175 - mae: 0.5092 - val_loss: 204.9975 - val_mae: 1.4970
# Epoch 4/100
# 59/59 [==============================] - 0s 2ms/step - loss: 3.5084 - mae: 0.6153 - val_loss: 204.7775 - val_mae: 1.4776
# Epoch 5/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.0497 - mae: 0.5240 - val_loss: 204.6118 - val_mae: 1.4650
# Epoch 6/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.1079 - mae: 0.4920 - val_loss: 204.5927 - val_mae: 1.4450
# Epoch 7/100
# 59/59 [==============================] - 0s 2ms/step - loss: 3.1503 - mae: 0.5674 - val_loss: 204.5426 - val_mae: 1.4382
# Epoch 8/100
# 59/59 [==============================] - 0s 2ms/step - loss: 4.2278 - mae: 0.5885 - val_loss: 204.5668 - val_mae: 1.4255
# Epoch 9/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.
100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6208 - mae: 0.3633 - val_loss: 204.6053 - val_mae: 1.4601
# Epoch 73/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6342 - mae: 0.3774 - val_loss: 204.5854 - val_mae: 1.4617
# Epoch 74/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5031 - mae: 0.3483 - val_loss: 204.5627 - val_mae: 1.4211
# Epoch 75/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.3659 - mae: 0.3356 - val_loss: 204.5366 - val_mae: 1.4200
# Epoch 76/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.7414 - mae: 0.3919 - val_loss: 204.5800 - val_mae: 1.4470
# Epoch 77/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.3805 - mae: 0.3836 - val_loss: 204.5237 - val_mae: 1.4201
# Epoch 78/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.7768 - mae: 0.3565 - val_loss: 204.5653 - val_mae: 1.4275
# Epoch 79/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6681 - mae: 0.3650 - val_loss: 204.5970 - val_mae: 1.4413
# Epoch 80/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.2448 - mae: 0.3845 - val_loss: 204.6545 - val_mae: 1.4345
# Epoch 81/100
# 59/59 [==============================] - 0s 2ms/step - loss: 3.3479 - mae: 0.5021 - val_loss: 204.7169 - val_mae: 1.4252
# Epoch 82/100
# 59/59 [==============================] - 0s 3ms/step - loss: 3.6941 - mae: 0.5086 - val_loss: 204.7059 - val_mae: 1.4187
# Epoch 83/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.3875 - mae: 0.3287 - val_loss: 204.7430 - val_mae: 1.4446
# Epoch 84/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.9490 - mae: 0.4389 - val_loss: 204.7694 - val_mae: 1.4308
# Epoch 85/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.9207 - mae: 0.3503 - val_loss: 204.7736 - val_mae: 1.4714
# Epoch 86/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.9831 - mae: 0.3946 - val_loss: 204.7579 - val_mae: 1.4615
# Epoch 87/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.7190 - mae: 0.3828 - val_loss: 204.8258 - val_mae: 1.4907
# Epoch 88/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6222 - mae: 0.3692 - val_loss: 204.8502 - val_mae: 1.4846
# Epoch 89/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.8288 - mae: 0.3768 - val_loss: 204.8235 - val_mae: 1.4597
# Epoch 90/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.3923 - mae: 0.4349 - val_loss: 204.7953 - val_mae: 1.4322
# Epoch 91/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.5371 - mae: 0.3522 - val_loss: 204.7686 - val_mae: 1.4428
# Epoch 92/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.6859 - mae: 0.3970 - val_loss: 204.7943 - val_mae: 1.4430
# Epoch 93/100
# 59/59 [==============================] - 0s 2ms/step - loss: 1.3073 - mae: 0.3982 - val_loss: 204.8261 - val_mae: 1.4520
# Epoch 94/100
# 59/59 [==============================] - 0s 1ms/step - loss: 2.0040 - mae: 0.4268 - val_loss: 204.9153 - val_mae: 1.4577
# Epoch 95/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.3900 - mae: 0.3930 - val_loss: 204.9702 - val_mae: 1.4704
# Epoch 96/100
# 59/59 [==============================] - 0s 2ms/step - loss: 2.0082 - mae: 0.4620 - val_loss: 204.9819 - val_mae: 1.4686
# Epoch 97/100
# 59/59 [==============================] - 0s 1ms/step - loss: 0.2932 - mae: 0.3255 - val_loss: 204.9935 - val_mae: 1.4634
# Epoch 98/100
# 59/59 [==============================] - 0s 1ms/step - loss: 2.7536 - mae: 0.4618 - val_loss: 204.9336 - val_mae: 1.4505
# Epoch 99/100
# 59/59 [==============================] - 0s 2ms/step - loss: 0.4010 - mae: 0.3416 - val_loss: 204.9806 - val_mae: 1.4644
# Epoch 100/100
# 59/59 [==============================] - 0s 1ms/step - loss: 1.0130 - mae: 0.3799 - val_loss: 204.9748 - val_mae: 1.4841

# %% [markdown]
# Parameters involved:
#     https://keras.io/api/models/model_training_apis/

# %%
#plot learning curves

#accuracy no idea what this is for
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model mean absolute error')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['mae', 'Validation mae'], loc='upper left')
plt.show()

#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss'], loc='upper left')#, 'Validation Loss'
plt.show()

# %%
#model evaluation
score = model.evaluate(X_test, y_test)[1]
score2= model.evaluate(X_test, y_test)[0]
# Out:
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9199 - mae: 0.6367
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9199 - mae: 0.6367

# %%
print('Accuracy without tuning: {}'.format(score))
print('Loss without tuning: {}'.format(score2))
# Out:
# Accuracy without tuning: 0.6366689801216125
# Loss without tuning: 1.9199458360671997

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                656
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# https://keras.io/api/models/sequential/
# The Sequential Class, provides a training and inference features on this model

# %%
y_pred = model.predict(X_test)

plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_pred, color = 'blue', label = 'Predicted data')
plt.title('Prediction')
plt.legend()
plt.show()

# %% [markdown]
# cite: https://stackoverflow.com/questions/49008074/how-to-create-a-neural-network-for-regression

# %%
#Why are my errors all of a sudden so because of overfitting?
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.6366689307258394
# Mean Squared Error: 1.9199459877246694
# Root Mean Squared Error: 1.3856211559169662

# %% [markdown]
# # Now Hyperparameter tuning

# %%
import kerastuner
from kerastuner import HyperModel

def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid']),#,'softmax']),
        input_dim = 40
        )
             
    )

    model.add(Dense(
        units=hp.Int('units', min_value=8, max_value=32, step=4), 
        activation = hp.Choice('dense_activation', 
                values=['relu', 'tanh','sigmoid'])#,'softmax'])
        )
             
    )
    
    model.add(
        keras.layers.Dropout(
            hp.Float(
                    'dropout',
                    min_value=0.0001,
                    max_value=0.1,
                    step=0.01)
        )
    )

    # Adding the output layer
    model.add(Dense(units = 1))


    model.compile(
        #optimizer='adam',
        optimizer = hp.Choice('dense_optimizer',
                values=['adam']),#,'SGD','rmsprop','adadelta'] ),
        loss = 'mean_squared_error',
        metrics = ['mae']
    )
    return model

# %%
tuner_rs = kerastuner.tuners.RandomSearch(
            build_model,
            objective='mae',
            max_trials=4,
            executions_per_trial=2, overwrite=True)

# %%
tuner_rs.search(X_train, y_train, epochs=100) #, verbose=0)
# Out:
# Trial 4 Complete [00h 00m 08s]
# mae: 0.8836176991462708
#
# Best mae So Far: 0.8104059994220734
# Total elapsed time: 00h 00m 33s
# INFO:tensorflow:Oracle triggered exit

# %%
#best_model = tuner_rs.get_best_models(num_models=1)
#best_model = tuner_rs.get_best_models(num_models=1)[0]
#mse_rs = best_model.evaluate(X_test, y_test)[1]

# %%
#loss, mse = best_model.evaluate(X_test, y_test)

# %%
#collect best hyperparameters to rebuild model
best_model = tuner_rs.get_best_hyperparameters()[0]
model = tuner_rs.hypermodel.build(best_model)
model.summary()

# %%
# Training the Model
history = model.fit(X_train, y_train, batch_size = 10, epochs = 100, validation_split=0.3, verbose = 0)

# %%
#loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Loss', 'Validation Loss'], loc='upper right')
plt.show()

# %%
# get new predicted values with Hyperparameters
y_best_model_pred = model.predict(X_test)

# %%
# plot predicted values against test values
plt.plot(y_test, color = 'red', label = 'Real data')
plt.plot(y_best_model_pred, color = 'blue', label = 'HP Predicted data')
plt.title('HP Prediction')
plt.legend(loc='upper right')
plt.show()

# %%
# checking the output metrics
from sklearn import metrics

y_hp_pred=y_best_model_pred

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_hp_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_hp_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_hp_pred)))

y_mean = np.mean(y_hp_pred)
y_std = np.std(y_hp_pred)
print('Output Standard Deviation:', y_std)
print('Output Mean:', y_mean)

# %%
tuner_rs.results_summary()
