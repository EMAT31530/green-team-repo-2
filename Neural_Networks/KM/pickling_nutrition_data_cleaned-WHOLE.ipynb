# %%
import pandas as pd

# %%
data = pd.read_excel(r'/Users/rachaelgreen/Desktop/Intro_to_ai/GitHub/ai-group-project-green-team/Nutrition_Cleaned_Carbon_Mapped_Single_Sheet.xlsx')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a2dfbe53a1a> in <module>
# ----> 1 data = pd.read_excel(r'/Users/rachaelgreen/Desktop/Intro_to_ai/GitHub/ai-group-project-green-team/Nutrition_Cleaned_Carbon_Mapped_Single_Sheet.xlsx')
#       2 data
#
# NameError: name 'pd' is not defined

# %%
nutrition_data_clean_whole = data
nutrition_data_clean_whole.to_pickle("./WHOLEnutrition_data_clean.pkl")

# %%
nutrition = pd.read_pickle("./WHOLEnutrition_data_clean.pkl")
nutrition
# Out:
#           ID                                               name   Food Group  \
# 0     167513  Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods
# 1     167516            Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods
# 2     167517     Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods
# 3     167518  Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods
# 4     167519        Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods
# ...      ...                                                ...          ...
# 1218  787165                                    Plantain Fried    Vegetables
# 1219  787271                                Romaine Lettuce Raw   Vegetables
# 1220  787408                                       Palak Paneer   Vegetables
# 1221  787523                                  Carrots Raw Salad   Vegetables
# 1222  788186                                   Corn on the cob    Vegetables
#
# ...
