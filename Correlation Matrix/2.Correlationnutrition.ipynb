# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
nutrition = pd.read_pickle("./nutrition_data_clean.pkl")
nutrition
# Out:
#                                                    name   Food Group Branded?  \
# 0     Pillsbury Cinnamon Rolls With Icing Refrigerat...  Baked Foods      NaN
# 1               Waffles Buttermilk Frozen Ready-To-Heat  Baked Foods        X
# 2        Waffle Buttermilk Frozen Ready-To-Heat Toasted  Baked Foods        X
# 3     Waffle Buttermilk Frozen Ready-To-Heat Microwaved  Baked Foods        X
# 4           Waffle Plain Frozen Ready-To-Heat Microwave  Baked Foods        X
# ...                                                 ...          ...      ...
# 1218                                    Plantain Fried    Vegetables      NaN
# 1219                                Romaine Lettuce Raw   Vegetables      NaN
# 1220                                       Palak Paneer   Vegetables      NaN
# 1221                                  Carrots Raw Salad   Vegetables      NaN
# 1222                                   Corn on the cob    Vegetables      NaN
#
#       Price (£)  Weight (GRAMS)  Price per Weight (£/100Gram)  \
# 0          1.70           260.0                      0.653846
# 1          1.50           567.0                      0.264550
# 2          1.50           567.0                      0.264550
# 3          1.50           567.0                      0.264550
# 4          1.50           567.0                      0.264550
# ...         ...             ...                           ...
# 1218       0.90            85.0                      1.058824
# 1219       1.00           400.0                      0.250000
# 1220       3.75           500.0                      0.750000
# 1221       0.41          1000.0                      0.041000
# 1222       1.50           875.0                      0.171429
#
#            Carbon Group  Land use (m2/100g)  GHG(kgco2eq/100g)  \
# 0       Bread products               0.3482             0.1441
# 1       Bread products               0.3482             0.1441
# 2       Bread products               0.3482             0.1441
# 3       Bread products               0.3482             0.1441
# 4       Bread products               0.3482             0.1441
# ...                 ...                 ...                ...
# 1218  Other vegetables               0.0310             0.0455
# 1219  Other vegetables               0.0310             0.0455
# 1220            Cheese               8.0642             2.1240
# 1221  Other vegetables               0.0310             0.0455
# 1222  Other vegetables               0.0310             0.0455
#
#       Water use (L/100g)  Acidifying emissions(kgSO2eq/100g)  \
# 0                   56.7                            0.001209
# 1                   56.7                            0.001209
# 2                   56.7                            0.001209
# 3                   56.7                            0.001209
# 4                   56.7                            0.001209
# ...                  ...                                 ...
# 1218                 8.3                            0.000531
# 1219                 8.3                            0.000531
# 1220               473.5                            0.014894
# 1221                 8.3                            0.000531
# 1222                 8.3                            0.000531
#
#       Eutr emissions  (kg PO43-eq per 100g)  Calories  Fat (g)  Protein (g)  \
# 0                                  0.000706       330    11.27         4.34
# 1                                  0.000706       273     9.22         6.58
# 2                                  0.000706       309     9.49         7.42
# 3                                  0.000706       289     9.40         6.92
# 4                                  0.000706       298     9.91         6.71
# ...                                     ...       ...      ...          ...
# 1218                               0.000186       241    10.16         1.66
# 1219                               0.000186        19     0.27         1.39
# 1220                               0.008875        96     6.84         5.23
# 1221                               0.000186       208    15.70         1.22
# 1222                               0.000186        67     1.22         2.28
#
#       Carbohydrate (g)  Sugars (g)  Fiber (g)  Cholesterol (mg)  \
# 0                53.42       21.34        1.4               0.0
# 1                41.05        4.30        2.2              15.0
# 2                48.39        4.41        2.6              13.0
# 3                44.16        4.50        2.4              16.0
# 4                45.41        5.04        2.4              16.0
# ...                ...         ...        ...               ...
# 1218             40.60       19.10        2.9               0.0
# 1219              3.78        0.71        3.1               0.0
# 1220              4.32        1.89        1.2               7.0
# 1221             17.17       11.23        2.3               9.0
# 1222             14.30        4.43        2.0               0.0
#
#       Saturated Fats (g)
# 0                  3.250
# 1                  1.898
# 2                  2.275
# 3                  2.057
# 4                  1.580
# ...                  ...
# 1218               1.507
# 1219               0.053
# 1220               1.486
# 1221               2.452
# 1222               0.244
#
# [1223 rows x 20 columns]

# %%
correlation_matrix = nutrition.corr()
correlation_matrix
# Out:
#                                        Price (£)  Weight (GRAMS)  \
# Price (£)                               1.000000        0.384508
# Weight (GRAMS)                          0.384508        1.000000
# Price per Weight (£/100Gram)            0.086075       -0.068685
# Land use (m2/100g)                      0.306517       -0.022182
# GHG(kgco2eq/100g)                       0.263910       -0.039701
# Water use (L/100g)                      0.062594       -0.097717
# Acidifying emissions(kgSO2eq/100g)      0.271851       -0.030673
# Eutr emissions  (kg PO43-eq per 100g)   0.270324       -0.073593
# Calories                               -0.000143       -0.216409
# Fat (g)                                 0.035581       -0.132092
# Protein (g)                             0.267890       -0.078142
# Carbohydrate (g)                       -0.212728       -0.169849
# Sugars (g)                             -0.103702       -0.106294
# Fiber (g)                              -0.151565       -0.151910
# Cholesterol (mg)                        0.171679       -0.029225
# Saturated Fats (g)                      0.048484       -0.107271
#
#                                        Price per Weight (£/100Gram)  \
# Price (£)                                                  0.086075
# Weight (GRAMS)                                            -0.068685
# Price per Weight (£/100Gram)                               1.000000
# Land use (m2/100g)                                         0.015511
# GHG(kgco2eq/100g)                                          0.020943
# Water use (L/100g)                                         0.004651
# Acidifying emissions(kgSO2eq/100g)                         0.035486
# Eutr emissions  (kg PO43-eq per 100g)                      0.036645
# Calories                                                   0.018215
# Fat (g)                                                    0.026795
# Protein (g)                                                0.063628
# Carbohydrate (g)                                          -0.025270
# Sugars (g)                                                -0.024804
# Fiber (g)                                                  0.031458
# Cholesterol (mg)                                           0.050336
# Saturated Fats (g)                                         0.030017
#
#                                        Land use (m2/100g)  GHG(kgco2eq/100g)  \
# Price (£)                                        0.306517           0.263910
# Weight (GRAMS)                                  -0.022182          -0.039701
# Price per Weight (£/100Gram)                     0.015511           0.020943
# Land use (m2/100g)                               1.000000           0.938601
# GHG(kgco2eq/100g)                                0.938601           1.000000
# Water use (L/100g)                               0.335792           0.294789
# Acidifying emissions(kgSO2eq/100g)               0.873268           0.932774
# Eutr emissions  (kg PO43-eq per 100g)            0.875830           0.939885
# Calories                                         0.012803          -0.005806
# Fat (g)                                          0.151511           0.138914
# Protein (g)                                      0.411362           0.408012
# Carbohydrate (g)                                -0.317597          -0.332479
# Sugars (g)                                      -0.189749          -0.177105
# Fiber (g)                                       -0.196954          -0.218094
# Cholesterol (mg)                                 0.318675           0.334152
# Saturated Fats (g)                               0.252492           0.250689
#
#                                        Water use (L/100g)  \
# Price (£)                                        0.062594
# Weight (GRAMS)                                  -0.097717
# Price per Weight (£/100Gram)                     0.004651
# Land use (m2/100g)                               0.335792
# GHG(kgco2eq/100g)                                0.294789
# Water use (L/100g)                               1.000000
# Acidifying emissions(kgSO2eq/100g)               0.500491
# Eutr emissions  (kg PO43-eq per 100g)            0.357305
# Calories                                         0.263984
# Fat (g)                                          0.399552
# Protein (g)                                      0.349628
# Carbohydrate (g)                                -0.188460
# Sugars (g)                                      -0.114413
# Fiber (g)                                       -0.141068
# Cholesterol (mg)                                 0.241894
# Saturated Fats (g)                               0.430727
#
#                                        Acidifying emissions(kgSO2eq/100g)  \
# Price (£)                                                        0.271851
# Weight (GRAMS)                                                  -0.030673
# Price per Weight (£/100Gram)                                     0.035486
# Land use (m2/100g)                                               0.873268
# GHG(kgco2eq/100g)                                                0.932774
# Water use (L/100g)                                               0.500491
# Acidifying emissions(kgSO2eq/100g)                               1.000000
# Eutr emissions  (kg PO43-eq per 100g)                            0.896107
# Calories                                                         0.033745
# Fat (g)                                                          0.223040
# Protein (g)                                                      0.527204
# Carbohydrate (g)                                                -0.417835
# Sugars (g)                                                      -0.245730
# Fiber (g)                                                       -0.269395
# Cholesterol (mg)                                                 0.459624
# Saturated Fats (g)                                               0.341631
#
#                                        Eutr emissions  (kg PO43-eq per 100g)  \
# Price (£)                                                           0.270324
# Weight (GRAMS)                                                     -0.073593
# Price per Weight (£/100Gram)                                        0.036645
# Land use (m2/100g)                                                  0.875830
# GHG(kgco2eq/100g)                                                   0.939885
# Water use (L/100g)                                                  0.357305
# Acidifying emissions(kgSO2eq/100g)                                  0.896107
# Eutr emissions  (kg PO43-eq per 100g)                               1.000000
# Calories                                                           -0.017012
# Fat (g)                                                             0.124701
# Protein (g)                                                         0.505593
# Carbohydrate (g)                                                   -0.365191
# Sugars (g)                                                         -0.237546
# Fiber (g)                                                          -0.184134
# Cholesterol (mg)                                                    0.365608
# Saturated Fats (g)                                                  0.208757
#
#                                        Calories   Fat (g)  Protein (g)  \
# Price (£)                             -0.000143  0.035581     0.267890
# Weight (GRAMS)                        -0.216409 -0.132092    -0.078142
# Price per Weight (£/100Gram)           0.018215  0.026795     0.063628
# Land use (m2/100g)                     0.012803  0.151511     0.411362
# GHG(kgco2eq/100g)                     -0.005806  0.138914     0.408012
# Water use (L/100g)                     0.263984  0.399552     0.349628
# Acidifying emissions(kgSO2eq/100g)     0.033745  0.223040     0.527204
# Eutr emissions  (kg PO43-eq per 100g) -0.017012  0.124701     0.505593
# Calories                               1.000000  0.766847     0.247470
# Fat (g)                                0.766847  1.000000     0.194222
# Protein (g)                            0.247470  0.194222     1.000000
# Carbohydrate (g)                       0.560091 -0.035843    -0.195993
# Sugars (g)                             0.325951 -0.000139    -0.289868
# Fiber (g)                              0.277763  0.055540     0.042262
# Cholesterol (mg)                       0.056735  0.177565     0.441537
# Saturated Fats (g)                     0.574561  0.768726     0.154209
#
#                                        Carbohydrate (g)  Sugars (g)  \
# Price (£)                                     -0.212728   -0.103702
# Weight (GRAMS)                                -0.169849   -0.106294
# Price per Weight (£/100Gram)                  -0.025270   -0.024804
# Land use (m2/100g)                            -0.317597   -0.189749
# GHG(kgco2eq/100g)                             -0.332479   -0.177105
# Water use (L/100g)                            -0.188460   -0.114413
# Acidifying emissions(kgSO2eq/100g)            -0.417835   -0.245730
# Eutr emissions  (kg PO43-eq per 100g)         -0.365191   -0.237546
# Calories                                       0.560091    0.325951
# Fat (g)                                       -0.035843   -0.000139
# Protein (g)                                   -0.195993   -0.289868
# Carbohydrate (g)                               1.000000    0.608177
# Sugars (g)                                     0.608177    1.000000
# Fiber (g)                                      0.452516    0.047112
# Cholesterol (mg)                              -0.305655   -0.182761
# Saturated Fats (g)                            -0.070945    0.034837
#
#                                        Fiber (g)  Cholesterol (mg)  \
# Price (£)                              -0.151565          0.171679
# Weight (GRAMS)                         -0.151910         -0.029225
# Price per Weight (£/100Gram)            0.031458          0.050336
# Land use (m2/100g)                     -0.196954          0.318675
# GHG(kgco2eq/100g)                      -0.218094          0.334152
# Water use (L/100g)                     -0.141068          0.241894
# Acidifying emissions(kgSO2eq/100g)     -0.269395          0.459624
# Eutr emissions  (kg PO43-eq per 100g)  -0.184134          0.365608
# Calories                                0.277763          0.056735
# Fat (g)                                 0.055540          0.177565
# Protein (g)                             0.042262          0.441537
# Carbohydrate (g)                        0.452516         -0.305655
# Sugars (g)                              0.047112         -0.182761
# Fiber (g)                               1.000000         -0.223497
# Cholesterol (mg)                       -0.223497          1.000000
# Saturated Fats (g)                     -0.051813          0.260560
#
#                                        Saturated Fats (g)
# Price (£)                                        0.048484
# Weight (GRAMS)                                  -0.107271
# Price per Weight (£/100Gram)                     0.030017
# Land use (m2/100g)                               0.252492
# GHG(kgco2eq/100g)                                0.250689
# Water use (L/100g)                               0.430727
# Acidifying emissions(kgSO2eq/100g)               0.341631
# Eutr emissions  (kg PO43-eq per 100g)            0.208757
# Calories                                         0.574561
# Fat (g)                                          0.768726
# Protein (g)                                      0.154209
# Carbohydrate (g)                                -0.070945
# Sugars (g)                                       0.034837
# Fiber (g)                                       -0.051813
# Cholesterol (mg)                                 0.260560
# Saturated Fats (g)                               1.000000

# %%
sn.heatmap(correlation_matrix, annot=True)
plt.show()
