# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
nutrition_data = pd.read_excel('https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/807016/McCance_Widdowsons_Composition_of_Foods_Integrated_Dataset_2019.xlsx', sheet_name="1.3 Proximates", header=0, usecols="A,B,H,J:M,O,Q,D")
nutrition_data
# Out:
#      Food Code                                          Food Name Group  \
# 0          NaN                                                NaN   NaN
# 1          NaN                                                NaN   NaN
# 2       13-145                             Ackee, canned, drained    DG
# 3       13-146                                        Agar, dried    DG
# 4       13-147                    Agar, dried, soaked and drained    DG
# ...        ...                                                ...   ...
# 2907    12-515            Yogurt, whole milk, twin pot, not fruit    BN
# 2908    12-531  Yogurt, whole milk, twin pot, thick and creamy...    BN
# 2909    11-960  Yorkshire pudding, made with semi-skimmed milk...    AT
# 2910   11-1135  Yorkshire pudding, made with skimmed milk, hom...    AT
# 2911   11-1146            Yorkshire pudding, made with whole milk    AT
#
#      Water (g) Protein (g) Fat (g) Carbohydrate (g) Energy (kcal) (kcal)  \
# 0        WATER        PROT     FAT              CHO                KCALS
# 1        Water     Protein     Fat     Carbohydrate                 kcal
# 2         76.7         2.9    15.2              0.8                  151
# 3          9.7         1.3     1.2               Tr                   16
# 4         84.2         0.2     0.1               Tr                    2
# ...        ...         ...     ...              ...                  ...
# 2907      68.4         4.2     5.6             21.5                  148
# 2908      74.7         4.1     3.2             16.2                  106
# 2909      58.1         6.7     8.3             25.6                  197
# 2910      60.1         6.8     7.4             25.9                  190
# 2911      57.7         6.7     9.8             25.8                  211
#
#      Starch (g) Total sugars (g)
# 0          STAR           TOTSUG
# 1        Starch     Total sugars
# 2            Tr              0.8
# 3           0.0               Tr
# 4           0.0               Tr
# ...         ...              ...
# 2907        3.3             18.2
# 2908        0.6             15.6
# 2909       22.1              3.5
# 2910       22.3              3.6
# 2911       22.3              3.4
#
# [2912 rows x 10 columns]

# %%
type(nutrition_data)
# Out:
# pandas.core.frame.DataFrame

# %%
y = data.iloc[0:5000, 12].values
# extracting the first 100 values purely because data set is organized conveniently - in first 100, first 50 is one class and second 50 is another class

y = np.where(y > 0, 1, -1)
# every element in our array that is red wine (class=1), set it to 1, otherwise -1

X = data.iloc[0:5000, 0:11].values
# this is now extracting the features which are column . and .

y
